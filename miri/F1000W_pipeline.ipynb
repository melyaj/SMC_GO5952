# %% [markdown]
# # F1000W JWST/MIRI Imaging Pipeline — SMC-SW-Bar-3 (GO-5952)
#
# Custom data reduction for JWST/MIRI F1000W (10 µm) imaging.
#
# WCS alignment uses shifts measured from F560W (see `F560W_pipeline.ipynb`).
#
# **Pipeline:** Stage 1 → fix_rateints → Stage 2 → apply F560W shifts → Lyot flag → Stage 3

# %% [markdown]
# ## 1. Configuration

# %%
# ═══════════════════════════════════════════════════════════
# CONFIGURATION
# ═══════════════════════════════════════════════════════════

# ─── Target ───────────────────────────────────────────────
FILT           = 'F1000W'
TARGET         = 'SMC-SW-Bar-3'
PROGRAM        = 'GO-5952'

# ─── Paths ────────────────────────────────────────────────
BASE_DIR       = '/Users/melyajou/SMC_GO5952/miri'
TILE1_BASE     = 'jw05952003001'          # tile 1 observation ID
TILE2_BASE     = 'jw05952003002'          # tile 2 observation ID

# ─── WCS shifts (arcsec) ─────────────────────────────────
# Measured from F560W alignment; applied to each tile
# before Stage 3 to correct absolute astrometry.
TILE1_SHIFTS   = [-0.1674, -0.1364]       # [delta_RA, delta_Dec]
TILE2_SHIFTS   = [-0.1584, -0.1352]

# ─── Lyot coronagraph artifact ───────────────────────────
LYOT_ROW       = 700
LYOT_COL       = 310

# ─── Stage 1 options ─────────────────────────────────────
IPC_SKIP       = True       # skip IPC correction (Karl's practice)
JUMP_THRESHOLD = 5.0        # sigma for jump detection (MAST uses 4.0)

# ─── Run flags ────────────────────────────────────────────
run_detector1  = False      # Stage 1: detector1 + fix_rateints
run_image2     = True      # Stage 2: image2 calibration
run_image3     = True       # Stage 3: final mosaic

# ─── Stage 3 options ─────────────────────────────────────
TWEAKREG       = False      # skip — WCS shifts already applied above
SKYMATCH       = False       # match sky levels between exposures
                            # NOTE: unreliable if overlaps contain bright extended emission
SKY_SUBTRACT   = False      # offset only, do not subtract
OUTLIER_DET    = True       # outlier rejection ON
PIXEL_SCALE    = 0.11       # output pixel scale (arcsec/pix)
PIXFRAC        = 1.0        # drizzle pixel fraction
KERNEL         = 'square'

# ─── Figures ─────────────────────────────────────────────
FIGSIZE_SINGLE = (12, 10)
FIGSIZE_DOUBLE = (22, 10)
CMAP           = 'afmhot'
FIG_DPI        = 200

# %% [markdown]
# ## 2. Setup

# %%
import os, sys, glob, warnings, time
import numpy as np
import matplotlib.pyplot as plt
import logging

logging.getLogger('stpipe').setLevel(logging.WARNING)
logging.getLogger('CRDS').setLevel(logging.WARNING)

os.environ['CRDS_PATH']       = '/Users/melyajou/SMC_GO5952/crds_cache'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'

from astropy.io import fits
from astropy.stats import sigma_clipped_stats, sigma_clip
from astropy.visualization import simple_norm
from jwst import datamodels
from jwst.datamodels import dqflags
from jwst.pipeline import calwebb_detector1, calwebb_image2, calwebb_image3
from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

sys.path.insert(0, '..')
from pipeline_utils import *

# Directories
stage0   = f'{BASE_DIR}/{FILT}/stage0'
stage1   = f'{BASE_DIR}/{FILT}/stage1'
stage2   = f'{BASE_DIR}/{FILT}/stage2'
stage3   = f'{BASE_DIR}/{FILT}/stage3'
fig_dir  = f'{BASE_DIR}/{FILT}/figures'
mast_dir = f'{BASE_DIR}/{FILT}/mast_reference'

for d in [stage0, stage1, stage2, stage3, fig_dir]:
    os.makedirs(d, exist_ok=True)

print(f'{TARGET} ({PROGRAM}) — {FILT}')
# Out:
# SMC-SW-Bar-3 (GO-5952) — F1000W

# %% [markdown]
# ## 3. Stage 1 — Detector1 + fix_rateints
#
# Ramp fitting on uncal files, then fix the rate/rateints averaging bug (Gordon).

# %%
uncal_files = sorted(glob.glob(f'{stage0}/*_uncal.fits'))
print(f'{len(uncal_files)} uncal files in stage0/')

if run_detector1:
    existing_rate = sorted(glob.glob(f'{stage1}/*_rate.fits'))
    if len(existing_rate) == len(uncal_files):
        print(f'Stage 1 already done: {len(existing_rate)} rate files -- skipping')
    else:
        print(f'Running Stage 1 on {len(uncal_files)} uncal files...')
        for i, f in enumerate(uncal_files):
            tile = 'T1' if TILE1_BASE in f else 'T2'
            print(f'  [{i+1}/{len(uncal_files)}] {tile} -- {os.path.basename(f)}')
            t0 = time.time()
            det1_dict = {
                'ipc': {'skip': IPC_SKIP},
                'jump': {'rejection_threshold': JUMP_THRESHOLD, 'maximum_cores': 'half'},
                'ramp_fit': {'maximum_cores': 'half'},
            }
            calwebb_detector1.Detector1Pipeline.call(
                f, steps=det1_dict, output_dir=stage1, save_results=True)
            print(f'    done in {(time.time()-t0)/60:.1f} min')

    # fix_rateints
    rate_files = sorted(glob.glob(f'{stage1}/*_rate.fits'))
    old_fixed = glob.glob(f'{stage1}/*_fixed_rate.fits') + glob.glob(f'{stage1}/*_fixed_rateints.fits')
    for f in old_fixed:
        os.remove(f)
    print(f'\nRunning fix_rateints on {len(rate_files)} files...')
    for f in rate_files:
        out = fix_rateints_to_rate(f)
        print(f'  {os.path.basename(f)} -> {os.path.basename(out)}')
else:
    print('Skipping Stage 1 (run_detector1 = False)')

fixed_rate_files = sorted(glob.glob(f'{stage1}/*_fixed_rate.fits'))
print(f'\n{len(fixed_rate_files)} fixed_rate files ready')
# Out:
# 8 uncal files in stage0/
# Skipping Stage 1 (run_detector1 = False)
#
# 8 fixed_rate files ready

# %% [markdown]
# ## 4. Stage 2 — Image2 (Flat Field + Photometric Calibration)
#
# Resample skipped — drizzle happens in Stage 3.

# %%
if run_image2:
    old_cal = glob.glob(f'{stage2}/*_cal.fits') + glob.glob(f'{stage2}/*_i2d.fits')
    for f in old_cal:
        os.remove(f)

    print(f'Running Stage 2 on {len(fixed_rate_files)} files...')
    for i, f in enumerate(fixed_rate_files):
        print(f'  [{i+1}/{len(fixed_rate_files)}] {os.path.basename(f)}')
        calwebb_image2.Image2Pipeline.call(
            f, steps={'resample': {'skip': True}},
            output_dir=stage2, save_results=True)
else:
    print('Skipping Stage 2 (run_image2 = False)')

cal_files = sorted(glob.glob(f'{stage2}/*_cal.fits'))
print(f'{len(cal_files)} cal files ready')
# Out:
# Running Stage 2 on 8 files...
#   [1/8] jw05952003001_06101_00001_mirimage_fixed_rate.fits
# 2026-03-28 04:35:22,782 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03
ference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits
# 2026-03-28 04:35:29,304 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-03-28 04:35:29,304 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-03-28 04:35:29,305 - jwst.photom.photom - INFO -  exp_type: MIR_IMAGE
# 2026-03-28 04:35:29,305 - jwst.photom.photom - INFO -  filter: F1000W
# 2026-03-28 04:35:29,327 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-03-28 04:35:29,327 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-03-28 04:35:29,328 - jwst.photom.photom - INFO -  subarray: FULL
# 2026-03-28 04:35:29,328 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.986152
# 2026-03-28 04:35:29,329 - jwst.photom.photom - INFO - PHOTMJSR value: 0.349636
# 2026-03-28 04:35:29,341 - stpipe.step - INFO - Step photom done
# 2026-03-28 04:35:29,415 - stpipe.step - INFO - Step resample running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003002_06101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-28 04:35:29,416 - stpipe.step - INFO - Step skipped.
# 2026-03-28 04:35:29,416 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003002_06101_00004_mirimage_fixed
# 2026-03-28 04:35:29,417 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-03-28 04:35:29,417 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1464.pmap
# 2026-03-28 04:35:29,496 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003002_06101_00004_mirimage_fixed_cal.fits
# 2026-03-28 04:35:29,496 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-03-28 04:35:29,496 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# 8 cal files ready

# %% [markdown]
# ## 5. Apply F560W WCS Shifts
#
# F560W (shortest wavelength) has the most point sources for tweakreg alignment.
# We reuse those shifts for all other MIRI filters.

# %%
# ─── Apply F560W shifts to cal files ─────────────────────
for f in glob.glob(f'{stage2}/*_wcs_cal.fits'):
    os.remove(f)

print(f'Applying F560W shifts:')
print(f'  T1: {TILE1_SHIFTS}')
print(f'  T2: {TILE2_SHIFTS}\n')

for cfile in cal_files:
    if TILE1_BASE in cfile:
        s, tile = TILE1_SHIFTS, 'T1'
    else:
        s, tile = TILE2_SHIFTS, 'T2'
    outfile = shift_wcs(cfile, s, "_wcs")
    print(f'  {tile}: {os.path.basename(outfile)}')

wcs_cal_files = sorted(glob.glob(f'{stage2}/*_wcs_cal.fits'))
print(f'\n{len(wcs_cal_files)} WCS-corrected cal files')
# Out:
# Applying F560W shifts:
#   T1: [-0.1674, -0.1364]
#   T2: [-0.1584, -0.1352]
#
#   T1: jw05952003001_06101_00001_mirimage_fixed_wcs_cal.fits
#   T1: jw05952003001_06101_00002_mirimage_fixed_wcs_cal.fits
#   T1: jw05952003001_06101_00003_mirimage_fixed_wcs_cal.fits
#   T1: jw05952003001_06101_00004_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_06101_00001_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_06101_00002_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_06101_00003_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_06101_00004_mirimage_fixed_wcs_cal.fits
#
# 8 WCS-corrected cal files

# %% [markdown]
# ## 6. Lyot Flag + Stage 3 — Final Mosaic

# %%
# ─── Flag Lyot ───────────────────────────────────────────
wcs_cal_files = sorted(glob.glob(f'{stage2}/*_wcs_cal.fits'))
for f in wcs_cal_files:
    flag_lyot(f, lyot_row=LYOT_ROW, lyot_col=LYOT_COL)
print(f'Lyot flagged in {len(wcs_cal_files)} files')
# Out:
# Lyot flagged in 8 files

# %%
# ─── Stage 3 — Final mosaic ──────────────────────────────
if run_image3:
    old_s3 = glob.glob(f'{stage3}/*')
    for f in old_s3:
        os.remove(f)

    asn_name = f'miri_{FILT}_final'
    asn = asn_from_list.asn_from_list(
        wcs_cal_files, rule=DMS_Level3_Base, product_name=asn_name)
    asn_file = f'{stage3}/{asn_name}.json'
    with open(asn_file, 'w') as fp:
        name, serialized = asn.dump(format='json')
        fp.write(serialized)

    im3_dict = {
        'tweakreg':          {'skip': not TWEAKREG},
        'skymatch':          {'skymethod': 'match', 'subtract': SKY_SUBTRACT, 'skip': not SKYMATCH},
        'outlier_detection': {'skip': not OUTLIER_DET, 'save_results': True},
        'resample':          {'kernel': KERNEL, 'pixel_scale': PIXEL_SCALE, 'pixfrac': PIXFRAC},
    }

    print('Running Stage 3 (final mosaic)...')
    calwebb_image3.Image3Pipeline.call(
        asn_file, steps=im3_dict, output_dir=stage3, save_results=True)
    print('Stage 3 complete')
else:
    print('Skipping Stage 3 (run_image3 = False)')

mosaic = sorted(glob.glob(f'{stage3}/*_i2d.fits'))[0]
print(f'Mosaic: {mosaic}')
# Out:
# /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/jwst/associations/association.py:234: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-03-28 04:35:32,748 - stpipe.step - INFO - PARS-TWEAKREGSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-tweakregstep_0012.asdf
# 2026-03-28 04:35:32,754 - stpipe.step - INFO - PARS-OUTLIERDETECTIONSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-outlierdetectionstep_0088.asdf
# 2026-03-28 04:35:32,759 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# Running Stage 3 (final mosaic)...
# 2026-03-28 04:35:32,765 - stpipe.step - INFO - PARS-SOURCECATALOGSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-sourcecatalogstep_0012.asdf
# 2026-03-28 04:35:32,775 - stpipe.step - INFO - Image3Pipeline instance created.
# 2026-03-28 04:35:32,776 - stpipe.step - INFO - AssignMTWcsStep instance created.
# 2026-03-28 04:35:32,777 - stpipe.step - INFO - TweakRegStep instance created.
# 2026-03-28 04:35:32,778 - stpipe.step - INFO - SkyMatchStep instance created.
# 2026-03-28 04:35:32,779 - stpipe.step - INFO - OutlierDetectionStep instance created.
# 2026-03-28 04:35:32,780 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-28 04:35:32,781 - stpipe.step - INFO - SourceCatalogStep instance created.
# 2026-03-28 04:35:32,861 - stpipe.step - INFO - Step Image3Pipeline running with args ('/Users/melyajou/SMC_GO5952/miri/F1000W/stage3/miri_F1000W_final.json',).
# 2026-03-28 04:35:32,870 - stpipe.step - INFO - Step Image3Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/miri/F1000W/stage3
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   in_memory: True
#   steps:
#     assign_mtwcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: assign_mtwcs
#       search_output_file: True
#       input_dir: ''
#     tweakreg:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_catalogs: False
#       use_custom_catalogs: False
#       catalog_format: ecsv
#       catfile: ''
#       starfinder: iraf
#       snr_threshold: 10.0
#       kernel_fwhm: 2.89
#       bkg_boxsize: 400
#       minsep_fwhm: 0.0
#       sigma_radius: 1.5
#       sharplo: 0.5
#       sharphi: 2.0
#       roundlo: 0.0
#       roundhi: 0.2
#       brightest: 200
#       peakmax: None
#       npixels: 10
#       connectivity: '8'
#       nlevels: 32
#       contrast: 0.001
#       multithresh_mode: exponential
#       localbkg_width: 0
#       apermask_method: correct
#       kron_params: None
#       deblend: True
#       enforce_user_order: False
#       expand_refcat: False
#       minobj: 15
#       fitgeometry: rshift
#       nclip: 3
#       sigma: 3
#       searchrad: 1.0
#       use2dhist: True
#       separation: 1.0
#       tolerance: 0.7
#       xoffset: 0.0
#       yoffset: 0.0
#       abs_refcat: ''
#       save_abs_catalog: False
#       abs_minobj: 15
#       abs_fitgeometry: rshift
#       abs_nclip: 3
#       abs_sigma: 3.0
#       abs_searchrad: 6.0
#       abs_use2dhist: True
#       abs_separation: 1.0
#       abs_tolerance: 0.7
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       in_memory: True
#     skymatch:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       skymethod: match
#       match_down: True
#       subtract: False
#       skylist: None
#       stepsize: None
#       skystat: mode
#       dqbits: ~DO_NOT_USE+NON_SCIENCE
#       lower: None
#       upper: None
#       nclip: 5
#       lsigma: 4.0
#       usigma: 4.0
#       binwidth: 0.1
#       in_memory: True
#     outlier_detection:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: True
#       skip: False
#       suffix: None
#       search_output_file: False
#       input_dir: ''
#       weight_type: exptime
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       maskpt: 0.7
#       snr: 4.0 3.0
#       scale: 1.0 0.8
#       backg: 0.0
#       kernel_size: 7 7
#       threshold_percent: 99.8
#       rolling_window_width: 25
#       ifu_second_check: False
#       save_intermediate_results: False
#       resample_data: True
#       good_bits: ~DO_NOT_USE+NON_SCIENCE
#       in_memory: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: 0.11
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#     source_catalog:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: cat
#       search_output_file: True
#       input_dir: ''
#       aperture_ee1: 30
#       aperture_ee2: 50
#       aperture_ee3: 70
#       ci1_star_threshold: 2.0
#       ci2_star_threshold: 1.8
#       starfinder: segmentation
#       snr_threshold: 3.0
#       bkg_boxsize: 1000
#       kernel_fwhm: 2.91
#       minsep_fwhm: 0.0
#       sigma_radius: 1.5
#       sharplo: 0.5
#       sharphi: 2.0
#       roundlo: 0.0
#       roundhi: 0.2
#       brightest: 200
#       peakmax: None
#       npixels: 5
#       connectivity: '8'
#       nlevels: 32
#       contrast: 0.001
#       multithresh_mode: exponential
#       localbkg_width: 0
#       apermask_method: correct
#       kron_params: None
#       deblend: False
# 2026-03-28 04:35:32,921 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'miri_F1000W_final.json' reftypes = ['abvegaoffset', 'apcorr']
# 2026-03-28 04:35:32,923 - stpipe.pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0002.asdf'.
# 2026-03-28 04:35:32,923 - stpipe.pipeline - INFO - Prefetch for APCORR reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_apcorr_0014.fits'.
# 2026-03-28 04:35:32,924 - jwst.pipeline.calwebb_image3 - INFO - Starting calwebb_image3 ...
# 2026-03-28 04:35:33,199 - stpipe.step - INFO - Step tweakreg running with args (<jwst.datamodels.library.ModelLibrary object at 0x13e621f50>,).
# 2026-03-28 04:35:33,199 - stpipe.step - INFO - Step skipped.
# 2026-03-28 04:35:33,861 - stpipe.step - INFO - Step skymatch running with args (<jwst.datamodels.library.ModelLibrary object at 0x13e621f50>,).
# 2026-03-28 04:35:33,862 - stpipe.step - INFO - Step skipped.
# 2026-03-28 04:35:33,965 - stpipe.step - INFO - Step outlier_detection running with args (<jwst.datamodels.library.ModelLibrary object at 0x13e621f50>,).
# 2026-03-28 04:35:33,966 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: imaging
# 2026-03-28 04:35:33,966 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-03-28 04:35:33,991 - jwst.resample.resample_utils - INFO - Pixel scale ratio (pscale_out/pscale_in): 1.0
# 2026-03-28 04:35:33,992 - jwst.resample.resample_utils - INFO - Computed output pixel scale: 0.11091996378835713 arcsec.
# 2026-03-28 04:35:34,000 - stcal.resample.resample - INFO - Output pixel scale: 0.11091996378835713 arcsec.
# 2026-03-28 04:35:34,001 - stcal.resample.resample - INFO - Driz parameter kernel: square
# 2026-03-28 04:35:34,001 - stcal.resample.resample - INFO - Driz parameter pixfrac: 1.0
# 2026-03-28 04:35:34,002 - stcal.resample.resample - INFO - Driz parameter fillval: NAN
# 2026-03-28 04:35:34,002 - stcal.resample.resample - INFO - Driz parameter weight_type: exptime
# 2026-03-28 04:35:34,004 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:35:34,306 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:34,446 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-28 04:35:34,480 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:35:34,755 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:34,892 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-28 04:35:34,923 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:35:35,193 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:35,329 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-28 04:35:35,359 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:35:35,628 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:35,763 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-28 04:35:35,794 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:35:36,068 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:36,205 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-28 04:35:36,238 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:35:36,507 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:36,643 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-28 04:35:36,672 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:35:36,943 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:37,080 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-28 04:35:37,108 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:35:37,383 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:37,520 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-28 04:35:38,549 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:35:38,587 - jwst.outlier_detection.utils - INFO - 8050 pixels marked as outliers
# 2026-03-28 04:35:38,905 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:35:38,942 - jwst.outlier_detection.utils - INFO - 7918 pixels marked as outliers
# 2026-03-28 04:35:39,261 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:35:39,300 - jwst.outlier_detection.utils - INFO - 6725 pixels marked as outliers
# 2026-03-28 04:35:39,616 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:35:39,655 - jwst.outlier_detection.utils - INFO - 6800 pixels marked as outliers
# 2026-03-28 04:35:39,972 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:35:40,007 - jwst.outlier_detection.utils - INFO - 4571 pixels marked as outliers
# 2026-03-28 04:35:40,323 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:35:40,363 - jwst.outlier_detection.utils - INFO - 5215 pixels marked as outliers
# 2026-03-28 04:35:40,691 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:35:40,728 - jwst.outlier_detection.utils - INFO - 7534 pixels marked as outliers
# 2026-03-28 04:35:41,040 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:35:41,076 - jwst.outlier_detection.utils - INFO - 5313 pixels marked as outliers
# 2026-03-28 04:35:41,175 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003001_06101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:35:41,253 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003001_06101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:35:41,338 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003001_06101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:35:41,416 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003001_06101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:35:41,495 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003002_06101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:35:41,591 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003002_06101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:35:41,670 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003002_06101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:35:41,749 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003002_06101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:35:41,749 - stpipe.step - INFO - Step outlier_detection done
# 2026-03-28 04:35:41,846 - stpipe.step - INFO - Step resample running with args (<jwst.datamodels.library.ModelLibrary object at 0x13e621f50>,).
# 2026-03-28 04:35:41,932 - jwst.resample.resample_utils - INFO - Output pixel scale: 0.10999999999999999 arcsec.
# 2026-03-28 04:35:41,933 - jwst.resample.resample_utils - INFO - Computed pixel scale ratio (pscale_out/pscale_in): 0.9970308890875107.
# 2026-03-28 04:35:41,940 - stcal.resample.resample - INFO - Output pixel scale: 0.10999999999999999 arcsec.
# 2026-03-28 04:35:41,941 - stcal.resample.resample - INFO - Driz parameter kernel: square
# 2026-03-28 04:35:41,941 - stcal.resample.resample - INFO - Driz parameter pixfrac: 1.0
# 2026-03-28 04:35:41,941 - stcal.resample.resample - INFO - Driz parameter fillval: NAN
# 2026-03-28 04:35:41,942 - stcal.resample.resample - INFO - Driz parameter weight_type: exptime
# 2026-03-28 04:35:41,951 - jwst.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:42,236 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:42,339 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:42,439 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:42,539 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:42,984 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:43,088 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:43,188 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:43,289 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:43,704 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:43,808 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:43,908 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:44,009 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:44,413 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:44,516 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:44,615 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:44,716 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:45,133 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:45,236 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:45,337 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:45,437 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:45,873 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:45,976 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:46,077 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:46,177 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:46,587 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:46,690 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:46,791 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:46,892 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:47,312 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:35:47,414 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:47,514 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:47,614 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:35:47,914 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420634 -73.347615616 11.249922731 -73.357480074 11.302084393 -73.410228323 11.423927195 -73.400333404
# 2026-03-28 04:35:48,060 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/miri_F1000W_final_i2d.fits
# 2026-03-28 04:35:48,060 - stpipe.step - INFO - Step resample done
# 2026-03-28 04:35:48,156 - stpipe.step - INFO - Step source_catalog running with args (<ImageModel(1184, 1794) from miri_F1000W_final_i2d.fits>,).
# 2026-03-28 04:35:48,232 - jwst.source_catalog.source_catalog_step - INFO - Using APCORR reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_apcorr_0014.fits
# 2026-03-28 04:35:48,235 - jwst.source_catalog.source_catalog_step - INFO - Using ABVEGAOFFSET reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0002.asdf
# 2026-03-28 04:35:48,236 - jwst.source_catalog.reference_data - INFO - Instrument: MIRI
# 2026-03-28 04:35:48,236 - jwst.source_catalog.reference_data - INFO - Detector: MIRIMAGE
# 2026-03-28 04:35:48,237 - jwst.source_catalog.reference_data - INFO - Filter: F1000W
# 2026-03-28 04:35:48,237 - jwst.source_catalog.reference_data - INFO - Subarray: FULL
# 2026-03-28 04:35:48,265 - jwst.source_catalog.reference_data - INFO - AB to Vega magnitude offset 4.95551
# 2026-03-28 04:35:48,413 - jwst.tweakreg.tweakreg_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1184, 1794).
# 2026-03-28 04:35:49,178 - jwst.source_catalog.source_catalog_step - INFO - Wrote source catalog: /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/miri_F1000W_final_cat.ecsv
# 2026-03-28 04:35:49,250 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/miri_F1000W_final_segm.fits
# 2026-03-28 04:35:49,251 - jwst.source_catalog.source_catalog_step - INFO - Wrote segmentation map: miri_F1000W_final_segm.fits
# 2026-03-28 04:35:49,253 - stpipe.step - INFO - Step source_catalog done
# 2026-03-28 04:35:49,256 - stpipe.step - INFO - Step Image3Pipeline done
# 2026-03-28 04:35:49,257 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# Stage 3 complete
# Mosaic: /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/miri_F1000W_final_i2d.fits

# %%
final_sci = load_mosaic(mosaic)
m_ours = get_stats(final_sci)
plot_mosaic(final_sci, f'Final — {FILT}', f'{FILT}_final.png',
            fig_dir=fig_dir, stats_txt=stats_label(*m_ours))

# %% [markdown]
# ## 7. Comparison with MAST

# %%
mast_i2d = sorted(glob.glob(f'{mast_dir}/*_i2d.fits'))
if mast_i2d:
    mast_sci = load_mosaic(mast_i2d[0])
    m_mast = get_stats(mast_sci)

    plot_comparison(final_sci, mast_sci,
                    'This work', 'MAST standard',
                    f'{FILT}_comparison.png', fig_dir=fig_dir,
                    stats1=stats_label(*m_ours), stats2=stats_label(*m_mast))

    print(f'This work: median = {m_ours[0]:.3f}, σ = {m_ours[1]:.3f} MJy/sr')
    print(f'MAST:      median = {m_mast[0]:.3f}, σ = {m_mast[1]:.3f} MJy/sr')
else:
    print('No MAST reference found')
# Out:
# This work: median = 12.093, σ = 0.305 MJy/sr
# MAST:      median = 11.977, σ = 0.300 MJy/sr

# %% [markdown]
# ## 8. Summary

# %%
line = '=' * 50
tweakreg_str = 'ON' if TWEAKREG else 'OFF'
skymatch_str = 'ON' if SKYMATCH else 'OFF'
skysub_str   = 'ON' if SKY_SUBTRACT else 'OFF'
outlier_str  = 'ON' if OUTLIER_DET else 'OFF'

print(line)
print(f'  {TARGET} ({PROGRAM}) — {FILT}')
print(line)
print()
if 'm_ours' in dir():
    print(f'  Result:')
    print(f'    median = {m_ours[0]:.3f} MJy/sr')
    print(f'    σ = {m_ours[1]:.3f} MJy/sr')
print()
print(f'  WCS shifts (from F560W):')
print(f'    Tile 1: {TILE1_SHIFTS}')
print(f'    Tile 2: {TILE2_SHIFTS}')
print()
print(f'  Stage 1:')
print(f'    IPC:              {"SKIP" if IPC_SKIP else "ON"}')
print(f'    Jump threshold:   {JUMP_THRESHOLD}σ')
print()
print(f'  Lyot flag: row>{LYOT_ROW}, col<{LYOT_COL}')
print()
print(f'  Stage 3:')
print(f'    Pixel scale:      {PIXEL_SCALE} arcsec/pix')
print(f'    Pixfrac:          {PIXFRAC}')
print(f'    Kernel:           {KERNEL}')
print(f'    Tweakreg:         {tweakreg_str}')
print(f'    Skymatch:         {skymatch_str}')
print(f'    Sky subtract:     {skysub_str}')
print(f'    Outlier det:      {outlier_str}')
print(line)
# Out:
# ==================================================
#   SMC-SW-Bar-3 (GO-5952) — F1000W
# ==================================================
#
#   Result:
#     median = 12.093 MJy/sr
#     σ = 0.305 MJy/sr
#
#   WCS shifts (from F560W):
#     Tile 1: [-0.1674, -0.1364]
#     Tile 2: [-0.1584, -0.1352]
#
#   Stage 1:
#     IPC:              SKIP
#     Jump threshold:   5.0σ
#
#   Lyot flag: row>700, col<310
#
#   Stage 3:
#     Pixel scale:      0.11 arcsec/pix
#     Pixfrac:          1.0
#     Kernel:           square
#     Tweakreg:         OFF
#     Skymatch:         OFF
#     Sky subtract:     OFF
#     Outlier det:      ON
# ==================================================
