# %% [markdown]
# # F1000W JWST/MIRI Imaging Pipeline — SMC-SW-Bar-3 (GO-5952)
#
# Custom data reduction for JWST/MIRI F1000W (10.0 µm) imaging.
#
# WCS alignment uses shifts measured from F560W (see `F560W_pipeline.ipynb`).
#
# **Pipeline:** Stage 1 → fix_rateints → Stage 2 → apply F560W shifts → Lyot flag → Stage 3

# %% [markdown]
# ## 1. Configuration

# %%
# ═══════════════════════════════════════════════════════════
# CONFIGURATION
# ═══════════════════════════════════════════════════════════

# ─── Target ───────────────────────────────────────────────
FILT           = 'F1000W'
TARGET         = 'SMC-SW-Bar-3'
PROGRAM        = 'GO-5952'

# ─── Paths ────────────────────────────────────────────────
BASE_DIR       = '/Users/melyajou/SMC_GO5952/miri'
TILE1_BASE     = 'jw05952003001'
TILE2_BASE     = 'jw05952003002'

# ─── WCS shifts (from F560W tweakreg) ────────────────────
TILE1_SHIFTS   = [-0.1674, -0.1364]
TILE2_SHIFTS   = [-0.1584, -0.1352]

# ─── Lyot coronagraph artifact ───────────────────────────
LYOT_ROW       = 700
LYOT_COL       = 310

# ─── Stage 1 options ─────────────────────────────────────
IPC_SKIP       = True       # skip IPC correction (Karl's practice)
JUMP_THRESHOLD = 5.0        # sigma for jump detection (MAST uses 4.0)

# ─── Run flags ────────────────────────────────────────────
run_detector1  = False       # Stage 1: detector1 + fix_rateints
run_image2     = True       # Stage 2: image2 calibration
run_image3     = True       # Stage 3: final mosaic

# ─── Stage 3 options ─────────────────────────────────────
TWEAKREG       = False      # skip — F560W shifts applied above
SKYMATCH       = False       # match sky levels between exposures
SKY_SUBTRACT   = False      # offset only, do not subtract
OUTLIER_DET    = True
PIXEL_SCALE    = 0.11       # arcsec/pix
PIXFRAC        = 1.0
KERNEL         = 'square'

# ─── Figures ─────────────────────────────────────────────
CMAP           = 'afmhot'
FIG_DPI        = 200

# %% [markdown]
# ## 2. Setup

# %%
import os, sys, glob, warnings, time
import numpy as np
import matplotlib.pyplot as plt
import logging

logging.getLogger('stpipe').setLevel(logging.WARNING)
logging.getLogger('CRDS').setLevel(logging.WARNING)

os.environ['CRDS_PATH']       = '/Users/melyajou/SMC_GO5952/crds_cache'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'

from astropy.io import fits
from astropy.stats import sigma_clipped_stats, sigma_clip
from jwst import datamodels
from jwst.datamodels import dqflags
from jwst.pipeline import calwebb_detector1, calwebb_image2, calwebb_image3
from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

sys.path.insert(0, '..')
from pipeline_utils import *

# Directories
stage0   = f'{BASE_DIR}/{FILT}/stage0'
stage1   = f'{BASE_DIR}/{FILT}/stage1'
stage2   = f'{BASE_DIR}/{FILT}/stage2'
stage3   = f'{BASE_DIR}/{FILT}/stage3'
fig_dir  = f'{BASE_DIR}/{FILT}/figures'
mast_dir = f'{BASE_DIR}/{FILT}/mast_reference'

for d in [stage0, stage1, stage2, stage3, fig_dir]:
    os.makedirs(d, exist_ok=True)

print(f'{TARGET} ({PROGRAM}) — {FILT}')
# Out:
# SMC-SW-Bar-3 (GO-5952) — F1000W

# %% [markdown]
# ## 3. Stage 1 — Detector1 + fix_rateints

# %%
uncal_files = sorted(glob.glob(f'{stage0}/*_uncal.fits'))
print(f'{len(uncal_files)} uncal files')

if run_detector1:
    fixed_rate_files = run_stage1(uncal_files, stage1, IPC_SKIP, JUMP_THRESHOLD, TILE1_BASE)
else:
    print('Skipping Stage 1 (run_detector1 = False)')
    fixed_rate_files = sorted(glob.glob(f'{stage1}/*_fixed_rate.fits'))
    print(f'{len(fixed_rate_files)} fixed_rate files ready')
# Out:
# 8 uncal files
# Skipping Stage 1 (run_detector1 = False)
# 8 fixed_rate files ready

# %% [markdown]
# ## 4. Stage 2 — Image2

# %%
if run_image2:
    cal_files = run_stage2(fixed_rate_files, stage2)
else:
    print('Skipping Stage 2 (run_image2 = False)')
    cal_files = sorted(glob.glob(f'{stage2}/*_cal.fits'))
    print(f'{len(cal_files)} cal files ready')
# Out:
# Running Stage 2 on 8 files...
#   [1/8] jw05952003001_06101_00001_mirimage_fixed_rate.fits
# 2026-03-30 15:10:55,170 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03-30 15:10:55,178 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-image2pipeline_0004.asdf
# 2026-03-30 15:10:55,185 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-03-30 15:10:55,186 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-03-30 15:10:55,186 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-03-30 15:10:55,187 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-03-30 15:10:55,188 - stpipe.step - INFO - PhotomStep instance created.
# 2026-03-30 15:10:55,188 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-30 15:10:55,262 - stpipe.step - INFO - Step Image2Pipeline running with args ('/Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00001_mirimage_fixed_rate.fits',).
# 2026-03-30 15:10:55,267 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/miri/F1000W/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 2.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
# 2026-03-30 15:10:55,291 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw05952003001_06101_00001_mirimage_fixed_rate.fits' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-03-30 15:10:55,293 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits'.
# 2026-03-30 15:10:55,294 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-03-30 15:10:55,294 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-03-30 15:10:55,294 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-03-30 15:10:55,295 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-03-30 15:10:55,295 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-03-30 15:10:55,295 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2026-03-30 15:10:55,296 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-03-30 15:10:55,296 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2026-03-30 15:10:55,296 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0842.fits'.
# 2026-03-30 15:10:55,297 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-03-30 15:10:55,297 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-03-30 15:10:55,298 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-03-30 15:10:55,298 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-03-30 15:10:55,298 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-03-30 15:10:55,298 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-03-30 15:10:55,299 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-03-30 15:10:55,299 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-03-30 15:10:55,299 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-03-30 15:10:55,300 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-03-30 15:10:55,300 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-03-30 15:10:55,300 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-03-30 15:10:55,300 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-03-30 15:10:55,301 - jwst.pipeline.calwebb_image2 - INFO - Processing product /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00001_mirimage_fixed
# 2026-03-30 15:10:55,301 - jwst.pipeline.calwebb_image2 - INFO - Working on input /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00001_mirimage_fixed_rate.fits ...
# 2026-03-30 15:10:55,413 - stpipe.step - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00001_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:55,522 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-03-30 15:10:55,560 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.372582646 -73.366777127 11.267528573 -73.375417007 11.297677560 -73.405628970 11.403355307 -73.397237738
# 2026-03-30 15:10:55,561 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  11.372582646 -73.366777127 11.267528573 -73.375417007 11.297677560 -73.405628970 11.403355307 -73.397237738
# 2026-03-30 15:10:55,561 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-03-30 15:10:55,577 - py.warnings - WARNING - /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/gwcs/wcs/_wcs.py:1803: LinAlgWarning: Failed to achieve requested SIP approximation accuracy.
#   fit_inv_poly_u, fit_inv_poly_v, max_inv_resid = fit_2D_poly(
#
# 2026-03-30 15:10:55,694 - stpipe.step - INFO - Step assign_wcs done
# 2026-03-30 15:10:55,768 - stpipe.step - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00001_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:55,803 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0842.fits
# 2026-03-30 15:10:55,804 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-03-30 15:10:55,804 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-03-30 15:10:55,804 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-03-30 15:10:55,860 - stpipe.step - INFO - Step flat_field done
# 2026-03-30 15:10:55,936 - stpipe.step - INFO - Step photom running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00001_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:55,947 - jwst.photom.photom_step - INFO - Using photom reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-03-30 15:10:55,948 - jwst.photom.photom_step - INFO - Using area reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits
# 2026-03-30 15:10:55,967 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-03-30 15:10:55,967 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-03-30 15:10:55,968 - jwst.photom.photom - INFO -  exp_type: MIR_IMAGE
# 2026-03-30 15:10:55,968 - jwst.photom.photom - INFO -  filter: F1000W
# 2026-03-30 15:10:55,996 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-03-30 15:10:55,996 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-03-30 15:10:55,997 - jwst.photom.photom - INFO -  subarray: FULL
# 2026-03-30 15:10:55,998 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.98616
# 2026-03-30 15:10:55,998 - jwst.photom.photom - INFO - PHOTMJSR value: 0.349633
# 2026-03-30 15:10:56,011 - stpipe.step - INFO - Step photom done
# 2026-03-30 15:10:56,086 - stpipe.step - INFO - Step resample running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00001_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:56,087 - stpipe.step - INFO - Step skipped.
# 2026-03-30 15:10:56,088 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00001_mirimage_fixed
# 2026-03-30 15:10:56,088 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-03-30 15:10:56,089 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1464.pmap
# 2026-03-30 15:10:56,176 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00001_mirimage_fixed_cal.fits
# 2026-03-30 15:10:56,176 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-03-30 15:10:56,177 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# 2026-03-30 15:10:56,207 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03-30 15:10:56,212 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-image2pipeline_0004.asdf
# 2026-03-30 15:10:56,218 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-03-30 15:10:56,219 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-03-30 15:10:56,220 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-03-30 15:10:56,220 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-03-30 15:10:56,221 - stpipe.step - INFO - PhotomStep instance created.
# 2026-03-30 15:10:56,222 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-30 15:10:56,296 - stpipe.step - INFO - Step Image2Pipeline running with args ('/Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00002_mirimage_fixed_rate.fits',).
# 2026-03-30 15:10:56,301 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/miri/F1000W/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 2.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
# 2026-03-30 15:10:56,316 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw05952003001_06101_00002_mirimage_fixed_rate.fits' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-03-30 15:10:56,318 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits'.
# 2026-03-30 15:10:56,318 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-03-30 15:10:56,319 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-03-30 15:10:56,319 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-03-30 15:10:56,319 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-03-30 15:10:56,320 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-03-30 15:10:56,320 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2026-03-30 15:10:56,321 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-03-30 15:10:56,321 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2026-03-30 15:10:56,321 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0842.fits'.
# 2026-03-30 15:10:56,322 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-03-30 15:10:56,322 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-03-30 15:10:56,322 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-03-30 15:10:56,323 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-03-30 15:10:56,323 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-03-30 15:10:56,323 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-03-30 15:10:56,323 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-03-30 15:10:56,324 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-03-30 15:10:56,324 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-03-30 15:10:56,324 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-03-30 15:10:56,325 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-03-30 15:10:56,325 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-03-30 15:10:56,325 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-03-30 15:10:56,326 - jwst.pipeline.calwebb_image2 - INFO - Processing product /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00002_mirimage_fixed
# 2026-03-30 15:10:56,326 - jwst.pipeline.calwebb_image2 - INFO - Working on input /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00002_mirimage_fixed_rate.fits ...
#   [2/8] jw05952003001_06101_00002_mirimage_fixed_rate.fits
# 2026-03-30 15:10:56,432 - stpipe.step - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00002_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:56,491 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-03-30 15:10:56,520 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.388470619 -73.365658876 11.283431424 -73.374306755 11.313606608 -73.404516421 11.419269614 -73.396117143
# 2026-03-30 15:10:56,521 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  11.388470619 -73.365658876 11.283431424 -73.374306755 11.313606608 -73.404516421 11.419269614 -73.396117143
# 2026-03-30 15:10:56,521 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-03-30 15:10:56,536 - py.warnings - WARNING - /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/gwcs/wcs/_wcs.py:1803: LinAlgWarning: Failed to achieve requested SIP approximation accuracy.
#   fit_inv_poly_u, fit_inv_poly_v, max_inv_resid = fit_2D_poly(
#
# 2026-03-30 15:10:56,544 - stpipe.step - INFO - Step assign_wcs done
# 2026-03-30 15:10:56,618 - stpipe.step - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00002_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:56,644 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0842.fits
# 2026-03-30 15:10:56,645 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-03-30 15:10:56,645 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-03-30 15:10:56,645 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-03-30 15:10:56,696 - stpipe.step - INFO - Step flat_field done
# 2026-03-30 15:10:56,777 - stpipe.step - INFO - Step photom running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00002_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:56,786 - jwst.photom.photom_step - INFO - Using photom reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-03-30 15:10:56,786 - jwst.photom.photom_step - INFO - Using area reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits
# 2026-03-30 15:10:56,804 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-03-30 15:10:56,804 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-03-30 15:10:56,804 - jwst.photom.photom - INFO -  exp_type: MIR_IMAGE
# 2026-03-30 15:10:56,805 - jwst.photom.photom - INFO -  filter: F1000W
# 2026-03-30 15:10:56,826 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-03-30 15:10:56,827 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-03-30 15:10:56,828 - jwst.photom.photom - INFO -  subarray: FULL
# 2026-03-30 15:10:56,828 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.98616
# 2026-03-30 15:10:56,829 - jwst.photom.photom - INFO - PHOTMJSR value: 0.349633
# 2026-03-30 15:10:56,841 - stpipe.step - INFO - Step photom done
# 2026-03-30 15:10:56,916 - stpipe.step - INFO - Step resample running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00002_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:56,917 - stpipe.step - INFO - Step skipped.
# 2026-03-30 15:10:56,918 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00002_mirimage_fixed
# 2026-03-30 15:10:56,918 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-03-30 15:10:56,919 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1464.pmap
# 2026-03-30 15:10:56,991 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00002_mirimage_fixed_cal.fits
# 2026-03-30 15:10:56,992 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-03-30 15:10:56,992 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# 2026-03-30 15:10:57,021 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03-30 15:10:57,025 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-image2pipeline_0004.asdf
# 2026-03-30 15:10:57,032 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-03-30 15:10:57,032 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-03-30 15:10:57,033 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-03-30 15:10:57,034 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-03-30 15:10:57,034 - stpipe.step - INFO - PhotomStep instance created.
# 2026-03-30 15:10:57,035 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-30 15:10:57,112 - stpipe.step - INFO - Step Image2Pipeline running with args ('/Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00003_mirimage_fixed_rate.fits',).
# 2026-03-30 15:10:57,118 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/miri/F1000W/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 2.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
# 2026-03-30 15:10:57,137 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw05952003001_06101_00003_mirimage_fixed_rate.fits' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-03-30 15:10:57,140 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits'.
# 2026-03-30 15:10:57,140 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-03-30 15:10:57,141 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-03-30 15:10:57,141 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-03-30 15:10:57,141 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-03-30 15:10:57,142 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-03-30 15:10:57,142 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2026-03-30 15:10:57,142 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-03-30 15:10:57,143 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2026-03-30 15:10:57,143 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0842.fits'.
# 2026-03-30 15:10:57,143 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-03-30 15:10:57,144 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-03-30 15:10:57,144 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-03-30 15:10:57,144 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-03-30 15:10:57,145 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-03-30 15:10:57,145 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-03-30 15:10:57,145 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-03-30 15:10:57,145 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-03-30 15:10:57,146 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-03-30 15:10:57,146 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-03-30 15:10:57,147 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-03-30 15:10:57,147 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-03-30 15:10:57,148 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-03-30 15:10:57,149 - jwst.pipeline.calwebb_image2 - INFO - Processing product /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00003_mirimage_fixed
# 2026-03-30 15:10:57,149 - jwst.pipeline.calwebb_image2 - INFO - Working on input /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00003_mirimage_fixed_rate.fits ...
#   [3/8] jw05952003001_06101_00003_mirimage_fixed_rate.fits
# 2026-03-30 15:10:57,259 - stpipe.step - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00003_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:57,320 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-03-30 15:10:57,350 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.390700587 -73.370079828 11.285635321 -73.378728774 11.315822054 -73.408938135 11.421511365 -73.400537778
# 2026-03-30 15:10:57,351 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  11.390700587 -73.370079828 11.285635321 -73.378728774 11.315822054 -73.408938135 11.421511365 -73.400537778
# 2026-03-30 15:10:57,351 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-03-30 15:10:57,365 - py.warnings - WARNING - /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/gwcs/wcs/_wcs.py:1803: LinAlgWarning: Failed to achieve requested SIP approximation accuracy.
#   fit_inv_poly_u, fit_inv_poly_v, max_inv_resid = fit_2D_poly(
#
# 2026-03-30 15:10:57,373 - stpipe.step - INFO - Step assign_wcs done
# 2026-03-30 15:10:57,446 - stpipe.step - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00003_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:57,471 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0842.fits
# 2026-03-30 15:10:57,471 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-03-30 15:10:57,472 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-03-30 15:10:57,472 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-03-30 15:10:57,522 - stpipe.step - INFO - Step flat_field done
# 2026-03-30 15:10:57,595 - stpipe.step - INFO - Step photom running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00003_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:57,603 - jwst.photom.photom_step - INFO - Using photom reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-03-30 15:10:57,604 - jwst.photom.photom_step - INFO - Using area reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits
# 2026-03-30 15:10:57,623 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-03-30 15:10:57,623 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-03-30 15:10:57,623 - jwst.photom.photom - INFO -  exp_type: MIR_IMAGE
# 2026-03-30 15:10:57,624 - jwst.photom.photom - INFO -  filter: F1000W
# 2026-03-30 15:10:57,647 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-03-30 15:10:57,648 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-03-30 15:10:57,649 - jwst.photom.photom - INFO -  subarray: FULL
# 2026-03-30 15:10:57,649 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.98616
# 2026-03-30 15:10:57,650 - jwst.photom.photom - INFO - PHOTMJSR value: 0.349633
# 2026-03-30 15:10:57,663 - stpipe.step - INFO - Step photom done
# 2026-03-30 15:10:57,740 - stpipe.step - INFO - Step resample running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00003_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:57,741 - stpipe.step - INFO - Step skipped.
# 2026-03-30 15:10:57,742 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00003_mirimage_fixed
# 2026-03-30 15:10:57,742 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-03-30 15:10:57,742 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1464.pmap
# 2026-03-30 15:10:57,821 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00003_mirimage_fixed_cal.fits
# 2026-03-30 15:10:57,821 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-03-30 15:10:57,821 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# 2026-03-30 15:10:57,851 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03-30 15:10:57,857 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-image2pipeline_0004.asdf
# 2026-03-30 15:10:57,863 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-03-30 15:10:57,863 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-03-30 15:10:57,864 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-03-30 15:10:57,865 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-03-30 15:10:57,865 - stpipe.step - INFO - PhotomStep instance created.
# 2026-03-30 15:10:57,866 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-30 15:10:57,994 - stpipe.step - INFO - Step Image2Pipeline running with args ('/Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00004_mirimage_fixed_rate.fits',).
# 2026-03-30 15:10:58,003 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/miri/F1000W/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 2.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
# 2026-03-30 15:10:58,027 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw05952003001_06101_00004_mirimage_fixed_rate.fits' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
#   [4/8] jw05952003001_06101_00004_mirimage_fixed_rate.fits
# 2026-03-30 15:10:58,030 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits'.
# 2026-03-30 15:10:58,031 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-03-30 15:10:58,031 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-03-30 15:10:58,031 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-03-30 15:10:58,032 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-03-30 15:10:58,032 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-03-30 15:10:58,032 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2026-03-30 15:10:58,033 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-03-30 15:10:58,033 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2026-03-30 15:10:58,033 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0842.fits'.
# 2026-03-30 15:10:58,034 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-03-30 15:10:58,034 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-03-30 15:10:58,034 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-03-30 15:10:58,035 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-03-30 15:10:58,035 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-03-30 15:10:58,036 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-03-30 15:10:58,036 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-03-30 15:10:58,037 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-03-30 15:10:58,037 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-03-30 15:10:58,037 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-03-30 15:10:58,038 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-03-30 15:10:58,038 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-03-30 15:10:58,038 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-03-30 15:10:58,039 - jwst.pipeline.calwebb_image2 - INFO - Processing product /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00004_mirimage_fixed
# 2026-03-30 15:10:58,039 - jwst.pipeline.calwebb_image2 - INFO - Working on input /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003001_06101_00004_mirimage_fixed_rate.fits ...
# 2026-03-30 15:10:58,178 - stpipe.step - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:58,242 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-03-30 15:10:58,276 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.377943352 -73.370412362 11.272869681 -73.379054960 11.303034639 -73.409266144 11.408732220 -73.400872174
# 2026-03-30 15:10:58,276 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  11.377943352 -73.370412362 11.272869681 -73.379054960 11.303034639 -73.409266144 11.408732220 -73.400872174
# 2026-03-30 15:10:58,277 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-03-30 15:10:58,293 - py.warnings - WARNING - /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/gwcs/wcs/_wcs.py:1803: LinAlgWarning: Failed to achieve requested SIP approximation accuracy.
#   fit_inv_poly_u, fit_inv_poly_v, max_inv_resid = fit_2D_poly(
#
# 2026-03-30 15:10:58,301 - stpipe.step - INFO - Step assign_wcs done
# 2026-03-30 15:10:58,382 - stpipe.step - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:58,413 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0842.fits
# 2026-03-30 15:10:58,414 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-03-30 15:10:58,415 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-03-30 15:10:58,415 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-03-30 15:10:58,465 - stpipe.step - INFO - Step flat_field done
# 2026-03-30 15:10:58,543 - stpipe.step - INFO - Step photom running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:58,551 - jwst.photom.photom_step - INFO - Using photom reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-03-30 15:10:58,552 - jwst.photom.photom_step - INFO - Using area reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits
# 2026-03-30 15:10:58,569 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-03-30 15:10:58,570 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-03-30 15:10:58,570 - jwst.photom.photom - INFO -  exp_type: MIR_IMAGE
# 2026-03-30 15:10:58,570 - jwst.photom.photom - INFO -  filter: F1000W
# 2026-03-30 15:10:58,592 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-03-30 15:10:58,593 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-03-30 15:10:58,593 - jwst.photom.photom - INFO -  subarray: FULL
# 2026-03-30 15:10:58,594 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.98616
# 2026-03-30 15:10:58,594 - jwst.photom.photom - INFO - PHOTMJSR value: 0.349633
# 2026-03-30 15:10:58,607 - stpipe.step - INFO - Step photom done
# 2026-03-30 15:10:58,685 - stpipe.step - INFO - Step resample running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003001_06101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:10:58,686 - stpipe.step - INFO - Step skipped.
# ...
# 2026-03-30 15:11:00,897 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  11.373367076 -73.352251739 11.268403006 -73.360892463 11.298529426 -73.391104161 11.404116502 -73.382712093
# 2026-03-30 15:11:00,898 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-03-30 15:11:00,912 - py.warnings - WARNING - /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/gwcs/wcs/_wcs.py:1803: LinAlgWarning: Failed to achieve requested SIP approximation accuracy.
#   fit_inv_poly_u, fit_inv_poly_v, max_inv_resid = fit_2D_poly(
#
# 2026-03-30 15:11:00,919 - stpipe.step - INFO - Step assign_wcs done
# 2026-03-30 15:11:00,994 - stpipe.step - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003002_06101_00003_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:11:01,020 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0842.fits
# 2026-03-30 15:11:01,020 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-03-30 15:11:01,021 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-03-30 15:11:01,021 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-03-30 15:11:01,128 - stpipe.step - INFO - Step flat_field done
# 2026-03-30 15:11:01,228 - stpipe.step - INFO - Step photom running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003002_06101_00003_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:11:01,237 - jwst.photom.photom_step - INFO - Using photom reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-03-30 15:11:01,237 - jwst.photom.photom_step - INFO - Using area reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits
# 2026-03-30 15:11:01,255 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-03-30 15:11:01,256 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-03-30 15:11:01,257 - jwst.photom.photom - INFO -  exp_type: MIR_IMAGE
# 2026-03-30 15:11:01,257 - jwst.photom.photom - INFO -  filter: F1000W
# 2026-03-30 15:11:01,280 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-03-30 15:11:01,280 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-03-30 15:11:01,281 - jwst.photom.photom - INFO -  subarray: FULL
# 2026-03-30 15:11:01,282 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.986152
# 2026-03-30 15:11:01,282 - jwst.photom.photom - INFO - PHOTMJSR value: 0.349636
# 2026-03-30 15:11:01,296 - stpipe.step - INFO - Step photom done
# 2026-03-30 15:11:01,379 - stpipe.step - INFO - Step resample running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003002_06101_00003_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:11:01,381 - stpipe.step - INFO - Step skipped.
# 2026-03-30 15:11:01,382 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003002_06101_00003_mirimage_fixed
# 2026-03-30 15:11:01,383 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-03-30 15:11:01,383 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1464.pmap
# 2026-03-30 15:11:01,455 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003002_06101_00003_mirimage_fixed_cal.fits
# 2026-03-30 15:11:01,456 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-03-30 15:11:01,456 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# 2026-03-30 15:11:01,486 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03-30 15:11:01,491 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-image2pipeline_0004.asdf
# 2026-03-30 15:11:01,497 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-03-30 15:11:01,498 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-03-30 15:11:01,498 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-03-30 15:11:01,499 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-03-30 15:11:01,499 - stpipe.step - INFO - PhotomStep instance created.
# 2026-03-30 15:11:01,500 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-30 15:11:01,579 - stpipe.step - INFO - Step Image2Pipeline running with args ('/Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003002_06101_00004_mirimage_fixed_rate.fits',).
# 2026-03-30 15:11:01,585 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/miri/F1000W/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 2.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
# 2026-03-30 15:11:01,605 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw05952003002_06101_00004_mirimage_fixed_rate.fits' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-03-30 15:11:01,607 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits'.
# 2026-03-30 15:11:01,608 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-03-30 15:11:01,608 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-03-30 15:11:01,608 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-03-30 15:11:01,609 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-03-30 15:11:01,609 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-03-30 15:11:01,609 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2026-03-30 15:11:01,609 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-03-30 15:11:01,610 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2026-03-30 15:11:01,610 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0842.fits'.
# 2026-03-30 15:11:01,610 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-03-30 15:11:01,611 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-03-30 15:11:01,611 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-03-30 15:11:01,612 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-03-30 15:11:01,612 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-03-30 15:11:01,613 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-03-30 15:11:01,613 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-03-30 15:11:01,613 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-03-30 15:11:01,614 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-03-30 15:11:01,614 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-03-30 15:11:01,615 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-03-30 15:11:01,615 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-03-30 15:11:01,615 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-03-30 15:11:01,616 - jwst.pipeline.calwebb_image2 - INFO - Processing product /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003002_06101_00004_mirimage_fixed
# 2026-03-30 15:11:01,616 - jwst.pipeline.calwebb_image2 - INFO - Working on input /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003002_06101_00004_mirimage_fixed_rate.fits ...
#   [8/8] jw05952003002_06101_00004_mirimage_fixed_rate.fits
# 2026-03-30 15:11:01,737 - stpipe.step - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003002_06101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:11:01,798 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-03-30 15:11:01,828 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.360620470 -73.352583260 11.255647911 -73.361217527 11.285752194 -73.391431077 11.391347622 -73.383045505
# 2026-03-30 15:11:01,829 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  11.360620470 -73.352583260 11.255647911 -73.361217527 11.285752194 -73.391431077 11.391347622 -73.383045505
# 2026-03-30 15:11:01,829 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-03-30 15:11:01,844 - py.warnings - WARNING - /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/gwcs/wcs/_wcs.py:1803: LinAlgWarning: Failed to achieve requested SIP approximation accuracy.
#   fit_inv_poly_u, fit_inv_poly_v, max_inv_resid = fit_2D_poly(
#
# 2026-03-30 15:11:01,853 - stpipe.step - INFO - Step assign_wcs done
# 2026-03-30 15:11:01,932 - stpipe.step - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003002_06101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:11:01,957 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0842.fits
# 2026-03-30 15:11:01,958 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-03-30 15:11:01,958 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-03-30 15:11:01,958 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-03-30 15:11:02,009 - stpipe.step - INFO - Step flat_field done
# 2026-03-30 15:11:02,089 - stpipe.step - INFO - Step photom running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003002_06101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:11:02,097 - jwst.photom.photom_step - INFO - Using photom reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-03-30 15:11:02,097 - jwst.photom.photom_step - INFO - Using area reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits
# 2026-03-30 15:11:02,115 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-03-30 15:11:02,115 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-03-30 15:11:02,115 - jwst.photom.photom - INFO -  exp_type: MIR_IMAGE
# 2026-03-30 15:11:02,116 - jwst.photom.photom - INFO -  filter: F1000W
# 2026-03-30 15:11:02,137 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-03-30 15:11:02,137 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-03-30 15:11:02,138 - jwst.photom.photom - INFO -  subarray: FULL
# 2026-03-30 15:11:02,139 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.986152
# 2026-03-30 15:11:02,139 - jwst.photom.photom - INFO - PHOTMJSR value: 0.349636
# 2026-03-30 15:11:02,151 - stpipe.step - INFO - Step photom done
# 2026-03-30 15:11:02,233 - stpipe.step - INFO - Step resample running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003002_06101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:11:02,234 - stpipe.step - INFO - Step skipped.
# 2026-03-30 15:11:02,235 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /Users/melyajou/SMC_GO5952/miri/F1000W/stage1/jw05952003002_06101_00004_mirimage_fixed
# 2026-03-30 15:11:02,236 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-03-30 15:11:02,236 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1464.pmap
# 2026-03-30 15:11:02,310 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage2/jw05952003002_06101_00004_mirimage_fixed_cal.fits
# 2026-03-30 15:11:02,310 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-03-30 15:11:02,311 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# 8 cal files ready

# %% [markdown]
# ## 5. Apply F560W WCS Shifts
#
# F560W has the most point sources for tweakreg. We reuse those shifts for all other filters.

# %%
wcs_cal_files = apply_tile_shifts(cal_files, TILE1_SHIFTS, TILE2_SHIFTS, TILE1_BASE)
# Out:
# Applying shifts:
#   T1: [-0.1674, -0.1364]
#   T2: [-0.1584, -0.1352]
#
#   T1: jw05952003001_06101_00001_mirimage_fixed_wcs_cal.fits
#   T1: jw05952003001_06101_00002_mirimage_fixed_wcs_cal.fits
#   T1: jw05952003001_06101_00003_mirimage_fixed_wcs_cal.fits
#   T1: jw05952003001_06101_00004_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_06101_00001_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_06101_00002_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_06101_00003_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_06101_00004_mirimage_fixed_wcs_cal.fits
#
# 8 WCS-corrected cal files

# %% [markdown]
# ## 6. Lyot Flag + Stage 3 — Final Mosaic

# %%
for f in wcs_cal_files:
    flag_lyot(f, lyot_row=LYOT_ROW, lyot_col=LYOT_COL)
print(f'Lyot flagged in {len(wcs_cal_files)} files')
# Out:
# Lyot flagged in 8 files

# %%
if run_image3:
    mosaic = run_stage3(
        wcs_cal_files, f'miri_{FILT}_final', stage3,
        tweakreg=TWEAKREG, skymatch=SKYMATCH, sky_subtract=SKY_SUBTRACT,
        outlier_det=OUTLIER_DET, pixel_scale=PIXEL_SCALE,
        pixfrac=PIXFRAC, kernel=KERNEL)
else:
    print('Skipping Stage 3 (run_image3 = False)')
    mosaic = sorted(glob.glob(f'{stage3}/*_i2d.fits'))[0]

print(f'Mosaic: {mosaic}')
# Out:
# /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/jwst/associations/association.py:234: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-03-30 15:11:05,511 - stpipe.step - INFO - PARS-TWEAKREGSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-tweakregstep_0012.asdf
# 2026-03-30 15:11:05,520 - stpipe.step - INFO - PARS-OUTLIERDETECTIONSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-outlierdetectionstep_0088.asdf
# 2026-03-30 15:11:05,525 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03-30 15:11:05,530 - stpipe.step - INFO - PARS-SOURCECATALOGSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-sourcecatalogstep_0012.asdf
# 2026-03-30 15:11:05,538 - stpipe.step - INFO - Image3Pipeline instance created.
# 2026-03-30 15:11:05,539 - stpipe.step - INFO - AssignMTWcsStep instance created.
# 2026-03-30 15:11:05,540 - stpipe.step - INFO - TweakRegStep instance created.
# 2026-03-30 15:11:05,541 - stpipe.step - INFO - SkyMatchStep instance created.
# 2026-03-30 15:11:05,541 - stpipe.step - INFO - OutlierDetectionStep instance created.
# 2026-03-30 15:11:05,542 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-30 15:11:05,543 - stpipe.step - INFO - SourceCatalogStep instance created.
# 2026-03-30 15:11:05,624 - stpipe.step - INFO - Step Image3Pipeline running with args ('/Users/melyajou/SMC_GO5952/miri/F1000W/stage3/miri_F1000W_final.json',).
# 2026-03-30 15:11:05,633 - stpipe.step - INFO - Step Image3Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/miri/F1000W/stage3
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   in_memory: True
#   steps:
#     assign_mtwcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: assign_mtwcs
#       search_output_file: True
#       input_dir: ''
#     tweakreg:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_catalogs: False
#       use_custom_catalogs: False
#       catalog_format: ecsv
#       catfile: ''
#       starfinder: iraf
#       snr_threshold: 10.0
#       kernel_fwhm: 2.89
#       bkg_boxsize: 400
#       minsep_fwhm: 0.0
#       sigma_radius: 1.5
#       sharplo: 0.5
#       sharphi: 2.0
#       roundlo: 0.0
#       roundhi: 0.2
#       brightest: 200
#       peakmax: None
#       npixels: 10
#       connectivity: '8'
#       nlevels: 32
#       contrast: 0.001
#       multithresh_mode: exponential
#       localbkg_width: 0
#       apermask_method: correct
#       kron_params: None
#       deblend: True
#       enforce_user_order: False
#       expand_refcat: False
#       minobj: 15
#       fitgeometry: rshift
#       nclip: 3
#       sigma: 3
#       searchrad: 1.0
#       use2dhist: True
#       separation: 1.0
#       tolerance: 0.7
#       xoffset: 0.0
#       yoffset: 0.0
#       abs_refcat: ''
#       save_abs_catalog: False
#       abs_minobj: 15
#       abs_fitgeometry: rshift
#       abs_nclip: 3
#       abs_sigma: 3.0
#       abs_searchrad: 6.0
#       abs_use2dhist: True
#       abs_separation: 1.0
#       abs_tolerance: 0.7
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       in_memory: True
#     skymatch:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       skymethod: match
#       match_down: True
#       subtract: False
#       skylist: None
#       stepsize: None
#       skystat: mode
#       dqbits: ~DO_NOT_USE+NON_SCIENCE
#       lower: None
#       upper: None
#       nclip: 5
#       lsigma: 4.0
#       usigma: 4.0
#       binwidth: 0.1
#       in_memory: True
#     outlier_detection:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: False
#       input_dir: ''
#       weight_type: exptime
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       maskpt: 0.7
#       snr: 4.0 3.0
#       scale: 1.0 0.8
#       backg: 0.0
#       kernel_size: 7 7
#       threshold_percent: 99.8
#       rolling_window_width: 25
#       ifu_second_check: False
#       save_intermediate_results: False
#       resample_data: True
#       good_bits: ~DO_NOT_USE+NON_SCIENCE
#       in_memory: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: 0.11
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#     source_catalog:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: cat
#       search_output_file: True
#       input_dir: ''
#       aperture_ee1: 30
#       aperture_ee2: 50
#       aperture_ee3: 70
#       ci1_star_threshold: 2.0
#       ci2_star_threshold: 1.8
#       starfinder: segmentation
#       snr_threshold: 3.0
#       bkg_boxsize: 1000
#       kernel_fwhm: 2.91
#       minsep_fwhm: 0.0
#       sigma_radius: 1.5
#       sharplo: 0.5
#       sharphi: 2.0
#       roundlo: 0.0
#       roundhi: 0.2
#       brightest: 200
#       peakmax: None
#       npixels: 5
#       connectivity: '8'
#       nlevels: 32
#       contrast: 0.001
#       multithresh_mode: exponential
#       localbkg_width: 0
#       apermask_method: correct
#       kron_params: None
#       deblend: False
# 2026-03-30 15:11:05,681 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'miri_F1000W_final.json' reftypes = ['abvegaoffset', 'apcorr']
# 2026-03-30 15:11:05,682 - stpipe.pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0002.asdf'.
# 2026-03-30 15:11:05,683 - stpipe.pipeline - INFO - Prefetch for APCORR reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_apcorr_0014.fits'.
# 2026-03-30 15:11:05,683 - jwst.pipeline.calwebb_image3 - INFO - Starting calwebb_image3 ...
# 2026-03-30 15:11:05,947 - stpipe.step - INFO - Step tweakreg running with args (<jwst.datamodels.library.ModelLibrary object at 0x1171b5e50>,).
# 2026-03-30 15:11:05,947 - stpipe.step - INFO - Step skipped.
# 2026-03-30 15:11:06,616 - stpipe.step - INFO - Step skymatch running with args (<jwst.datamodels.library.ModelLibrary object at 0x1171b5e50>,).
# 2026-03-30 15:11:06,617 - stpipe.step - INFO - Step skipped.
# 2026-03-30 15:11:06,725 - stpipe.step - INFO - Step outlier_detection running with args (<jwst.datamodels.library.ModelLibrary object at 0x1171b5e50>,).
# 2026-03-30 15:11:06,726 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: imaging
# 2026-03-30 15:11:06,727 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-03-30 15:11:06,752 - jwst.resample.resample_utils - INFO - Pixel scale ratio (pscale_out/pscale_in): 1.0
# 2026-03-30 15:11:06,753 - jwst.resample.resample_utils - INFO - Computed output pixel scale: 0.11091996378835713 arcsec.
# 2026-03-30 15:11:06,761 - stcal.resample.resample - INFO - Output pixel scale: 0.11091996378835713 arcsec.
# 2026-03-30 15:11:06,762 - stcal.resample.resample - INFO - Driz parameter kernel: square
# 2026-03-30 15:11:06,762 - stcal.resample.resample - INFO - Driz parameter pixfrac: 1.0
# 2026-03-30 15:11:06,762 - stcal.resample.resample - INFO - Driz parameter fillval: NAN
# 2026-03-30 15:11:06,763 - stcal.resample.resample - INFO - Driz parameter weight_type: exptime
# 2026-03-30 15:11:06,765 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:11:07,083 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:07,223 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-30 15:11:07,253 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:11:07,535 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:07,675 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-30 15:11:07,705 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:11:07,995 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:08,135 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-30 15:11:08,164 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:11:08,476 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:08,615 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-30 15:11:08,644 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:11:08,937 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:09,077 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-30 15:11:09,107 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:11:09,394 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:09,533 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-30 15:11:09,562 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:11:09,854 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:09,992 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-30 15:11:10,022 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:11:10,303 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:10,441 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420941 -73.347615458 11.249838138 -73.357486781 11.301996010 -73.410231474 11.423923930 -73.400329671
# 2026-03-30 15:11:11,503 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:11:11,540 - jwst.outlier_detection.utils - INFO - 8050 pixels marked as outliers
# 2026-03-30 15:11:11,880 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:11:11,918 - jwst.outlier_detection.utils - INFO - 7918 pixels marked as outliers
# 2026-03-30 15:11:12,252 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:11:12,288 - jwst.outlier_detection.utils - INFO - 6725 pixels marked as outliers
# 2026-03-30 15:11:12,648 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:11:12,689 - jwst.outlier_detection.utils - INFO - 6800 pixels marked as outliers
# 2026-03-30 15:11:13,026 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:11:13,062 - jwst.outlier_detection.utils - INFO - 4571 pixels marked as outliers
# 2026-03-30 15:11:13,396 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:11:13,430 - jwst.outlier_detection.utils - INFO - 5215 pixels marked as outliers
# 2026-03-30 15:11:13,755 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:11:13,794 - jwst.outlier_detection.utils - INFO - 7534 pixels marked as outliers
# 2026-03-30 15:11:14,124 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:11:14,161 - jwst.outlier_detection.utils - INFO - 5313 pixels marked as outliers
# 2026-03-30 15:11:14,272 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003001_06101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:11:14,352 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003001_06101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:11:14,434 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003001_06101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:11:14,515 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003001_06101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:11:14,594 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003002_06101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:11:14,672 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003002_06101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:11:14,753 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003002_06101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:11:14,833 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/jw05952003002_06101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:11:14,834 - stpipe.step - INFO - Step outlier_detection done
# 2026-03-30 15:11:14,930 - stpipe.step - INFO - Step resample running with args (<jwst.datamodels.library.ModelLibrary object at 0x1171b5e50>,).
# 2026-03-30 15:11:15,022 - jwst.resample.resample_utils - INFO - Output pixel scale: 0.10999999999999999 arcsec.
# 2026-03-30 15:11:15,022 - jwst.resample.resample_utils - INFO - Computed pixel scale ratio (pscale_out/pscale_in): 0.9970308890875107.
# 2026-03-30 15:11:15,030 - stcal.resample.resample - INFO - Output pixel scale: 0.10999999999999999 arcsec.
# 2026-03-30 15:11:15,031 - stcal.resample.resample - INFO - Driz parameter kernel: square
# 2026-03-30 15:11:15,031 - stcal.resample.resample - INFO - Driz parameter pixfrac: 1.0
# 2026-03-30 15:11:15,031 - stcal.resample.resample - INFO - Driz parameter fillval: NAN
# 2026-03-30 15:11:15,032 - stcal.resample.resample - INFO - Driz parameter weight_type: exptime
# 2026-03-30 15:11:15,042 - jwst.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:15,349 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:15,453 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:15,557 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:15,657 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:16,129 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:16,233 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:16,334 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:16,436 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:16,995 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:17,101 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:17,203 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:17,307 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:17,745 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:17,850 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:17,953 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:18,056 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:18,505 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:18,609 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:18,711 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:18,813 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:19,246 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:19,350 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:19,451 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:19,555 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:19,982 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:20,086 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:20,187 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:20,287 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:20,715 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:11:20,821 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:20,923 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:21,025 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:11:21,336 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371420634 -73.347615616 11.249922731 -73.357480074 11.302084393 -73.410228323 11.423927195 -73.400333404
# 2026-03-30 15:11:21,482 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/miri_F1000W_final_i2d.fits
# 2026-03-30 15:11:21,483 - stpipe.step - INFO - Step resample done
# 2026-03-30 15:11:21,587 - stpipe.step - INFO - Step source_catalog running with args (<ImageModel(1184, 1794) from miri_F1000W_final_i2d.fits>,).
# 2026-03-30 15:11:21,663 - jwst.source_catalog.source_catalog_step - INFO - Using APCORR reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_apcorr_0014.fits
# 2026-03-30 15:11:21,666 - jwst.source_catalog.source_catalog_step - INFO - Using ABVEGAOFFSET reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0002.asdf
# 2026-03-30 15:11:21,666 - jwst.source_catalog.reference_data - INFO - Instrument: MIRI
# 2026-03-30 15:11:21,667 - jwst.source_catalog.reference_data - INFO - Detector: MIRIMAGE
# 2026-03-30 15:11:21,667 - jwst.source_catalog.reference_data - INFO - Filter: F1000W
# 2026-03-30 15:11:21,667 - jwst.source_catalog.reference_data - INFO - Subarray: FULL
# 2026-03-30 15:11:21,696 - jwst.source_catalog.reference_data - INFO - AB to Vega magnitude offset 4.95551
# 2026-03-30 15:11:21,844 - jwst.tweakreg.tweakreg_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1184, 1794).
# 2026-03-30 15:11:22,726 - jwst.source_catalog.source_catalog_step - INFO - Wrote source catalog: /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/miri_F1000W_final_cat.ecsv
# 2026-03-30 15:11:22,795 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/miri_F1000W_final_segm.fits
# 2026-03-30 15:11:22,795 - jwst.source_catalog.source_catalog_step - INFO - Wrote segmentation map: miri_F1000W_final_segm.fits
# 2026-03-30 15:11:22,797 - stpipe.step - INFO - Step source_catalog done
# 2026-03-30 15:11:22,800 - stpipe.step - INFO - Step Image3Pipeline done
# 2026-03-30 15:11:22,801 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# Mosaic: /Users/melyajou/SMC_GO5952/miri/F1000W/stage3/miri_F1000W_final_i2d.fits

# %%
final_sci = load_mosaic(mosaic)
m_ours = get_stats(final_sci)
plot_mosaic(final_sci, f'Final — {FILT}', f'{FILT}_final.png',
            fig_dir=fig_dir, stats_txt=stats_label(*m_ours))

# %% [markdown]
# ## 7. Comparison with MAST

# %%
mast_i2d = sorted(glob.glob(f'{mast_dir}/*_i2d.fits'))
if mast_i2d:
    mast_sci = load_mosaic(mast_i2d[0])
    m_mast = get_stats(mast_sci)
    plot_comparison(final_sci, mast_sci,
                    'This work', 'MAST standard',
                    f'{FILT}_comparison.png', fig_dir=fig_dir,
                    stats1=stats_label(*m_ours), stats2=stats_label(*m_mast))
    print(f'This work: σ = {m_ours[1]:.3f} MJy/sr')
    print(f'MAST:      σ = {m_mast[1]:.3f} MJy/sr')
else:
    print('No MAST reference found')
# Out:
# This work: σ = 0.305 MJy/sr
# MAST:      σ = 0.300 MJy/sr

# %% [markdown]
# ## 8. Source Catalog

# %%
plot_source_catalog(stage3, final_sci, FILT, fig_dir=fig_dir, dpi=FIG_DPI)
# Out:
# Catalog: 269 sources

# %% [markdown]
# ## 9. Summary

# %%
print_pipeline_summary(
    TARGET, PROGRAM, FILT, m_ours=m_ours,
    tile1_shifts=TILE1_SHIFTS, tile2_shifts=TILE2_SHIFTS,
    ipc_skip=IPC_SKIP, jump_threshold=JUMP_THRESHOLD,
    lyot_row=LYOT_ROW, lyot_col=LYOT_COL,
    pixel_scale=PIXEL_SCALE, pixfrac=PIXFRAC, kernel=KERNEL,
    tweakreg=TWEAKREG, skymatch=SKYMATCH,
    sky_subtract=SKY_SUBTRACT, outlier_det=OUTLIER_DET)
# Out:
# ==================================================
#   SMC-SW-Bar-3 (GO-5952) — F1000W
# ==================================================
#
#   Result:
#     median = 12.093 MJy/sr
#     σ = 0.305 MJy/sr
#
#   WCS shifts:
#     Tile 1: [-0.1674, -0.1364]
#     Tile 2: [-0.1584, -0.1352]
#
#   Stage 1:
#     IPC:              SKIP
#     Jump threshold:   5.0σ
#
#   Lyot flag: row>700, col<310
#
#   Stage 3:
#     Pixel scale:      0.11 arcsec/pix
#     Pixfrac:          1.0
#     Kernel:           square
#     Tweakreg:         OFF
#     Skymatch:         OFF
#     Sky subtract:     OFF
#     Outlier det:      ON
# ==================================================
