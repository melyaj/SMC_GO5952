# %% [markdown]
# # F770W JWST/MIRI Imaging Pipeline — SMC-SW-Bar-3 (GO-5952)
#
# Custom data reduction for JWST/MIRI F770W (7.7 µm) imaging.
#
# WCS alignment uses shifts measured from F560W (see `F560W_pipeline.ipynb`).
#
# **Pipeline:** Stage 1 → fix_rateints → Stage 2 → apply F560W shifts → Lyot flag → Stage 3

# %% [markdown]
# ## 1. Configuration

# %%
# ═══════════════════════════════════════════════════════════
# CONFIGURATION
# ═══════════════════════════════════════════════════════════

# ─── Target ───────────────────────────────────────────────
FILT           = 'F770W'
TARGET         = 'SMC-SW-Bar-3'
PROGRAM        = 'GO-5952'

# ─── Paths ────────────────────────────────────────────────
BASE_DIR       = '/Users/melyajou/SMC_GO5952/miri'
TILE1_BASE     = 'jw05952003001'          # tile 1 observation ID
TILE2_BASE     = 'jw05952003002'          # tile 2 observation ID

# ─── WCS shifts (arcsec) ─────────────────────────────────
# Measured from F560W alignment; applied to each tile
# before Stage 3 to correct absolute astrometry.
TILE1_SHIFTS   = [-0.1674, -0.1364]       # [delta_RA, delta_Dec]
TILE2_SHIFTS   = [-0.1584, -0.1352]

# ─── Lyot coronagraph artifact ───────────────────────────
LYOT_ROW       = 700
LYOT_COL       = 310

# ─── Stage 1 options ─────────────────────────────────────
IPC_SKIP       = True       # skip IPC correction (Karl's practice)
JUMP_THRESHOLD = 5.0        # sigma for jump detection (MAST uses 4.0)

# ─── Run flags ────────────────────────────────────────────
run_detector1  = False      # Stage 1: detector1 + fix_rateints
run_image2     = True      # Stage 2: image2 calibration
run_image3     = True       # Stage 3: final mosaic

# ─── Stage 3 options ─────────────────────────────────────
TWEAKREG       = False      # skip — WCS shifts already applied above
SKYMATCH       = False       # match sky levels between exposures
                            # NOTE: unreliable if overlaps contain bright extended emission
SKY_SUBTRACT   = False      # offset only, do not subtract
OUTLIER_DET    = True       # outlier rejection ON
PIXEL_SCALE    = 0.11       # output pixel scale (arcsec/pix)
PIXFRAC        = 1.0        # drizzle pixel fraction
KERNEL         = 'square'

# ─── Figures ─────────────────────────────────────────────
FIGSIZE_SINGLE = (12, 10)
FIGSIZE_DOUBLE = (22, 10)
CMAP           = 'afmhot'
FIG_DPI        = 200

# %% [markdown]
# ## 2. Setup

# %%
import os, sys, glob, warnings, time
import numpy as np
import matplotlib.pyplot as plt
import logging

logging.getLogger('stpipe').setLevel(logging.WARNING)
logging.getLogger('CRDS').setLevel(logging.WARNING)

os.environ['CRDS_PATH']       = '/Users/melyajou/SMC_GO5952/crds_cache'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'

from astropy.io import fits
from astropy.stats import sigma_clipped_stats, sigma_clip
from astropy.visualization import simple_norm
from jwst import datamodels
from jwst.datamodels import dqflags
from jwst.pipeline import calwebb_detector1, calwebb_image2, calwebb_image3
from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

sys.path.insert(0, '..')
from pipeline_utils import *

# Directories
stage0   = f'{BASE_DIR}/{FILT}/stage0'
stage1   = f'{BASE_DIR}/{FILT}/stage1'
stage2   = f'{BASE_DIR}/{FILT}/stage2'
stage3   = f'{BASE_DIR}/{FILT}/stage3'
fig_dir  = f'{BASE_DIR}/{FILT}/figures'
mast_dir = f'{BASE_DIR}/{FILT}/mast_reference'

for d in [stage0, stage1, stage2, stage3, fig_dir]:
    os.makedirs(d, exist_ok=True)

print(f'{TARGET} ({PROGRAM}) — {FILT}')
# Out:
# SMC-SW-Bar-3 (GO-5952) — F770W

# %% [markdown]
# ## 3. Stage 1 — Detector1 + fix_rateints
#
# Ramp fitting on uncal files, then fix the rate/rateints averaging bug (Gordon).

# %%
uncal_files = sorted(glob.glob(f'{stage0}/*_uncal.fits'))
print(f'{len(uncal_files)} uncal files in stage0/')

if run_detector1:
    existing_rate = sorted(glob.glob(f'{stage1}/*_rate.fits'))
    if len(existing_rate) == len(uncal_files):
        print(f'Stage 1 already done: {len(existing_rate)} rate files -- skipping')
    else:
        print(f'Running Stage 1 on {len(uncal_files)} uncal files...')
        for i, f in enumerate(uncal_files):
            tile = 'T1' if TILE1_BASE in f else 'T2'
            print(f'  [{i+1}/{len(uncal_files)}] {tile} -- {os.path.basename(f)}')
            t0 = time.time()
            det1_dict = {
                'ipc': {'skip': IPC_SKIP},
                'jump': {'rejection_threshold': JUMP_THRESHOLD, 'maximum_cores': 'half'},
                'ramp_fit': {'maximum_cores': 'half'},
            }
            calwebb_detector1.Detector1Pipeline.call(
                f, steps=det1_dict, output_dir=stage1, save_results=True)
            print(f'    done in {(time.time()-t0)/60:.1f} min')

    # fix_rateints
    rate_files = sorted(glob.glob(f'{stage1}/*_rate.fits'))
    old_fixed = glob.glob(f'{stage1}/*_fixed_rate.fits') + glob.glob(f'{stage1}/*_fixed_rateints.fits')
    for f in old_fixed:
        os.remove(f)
    print(f'\nRunning fix_rateints on {len(rate_files)} files...')
    for f in rate_files:
        out = fix_rateints_to_rate(f)
        print(f'  {os.path.basename(f)} -> {os.path.basename(out)}')
else:
    print('Skipping Stage 1 (run_detector1 = False)')

fixed_rate_files = sorted(glob.glob(f'{stage1}/*_fixed_rate.fits'))
print(f'\n{len(fixed_rate_files)} fixed_rate files ready')
# Out:
# 8 uncal files in stage0/
# Skipping Stage 1 (run_detector1 = False)
#
# 8 fixed_rate files ready

# %% [markdown]
# ## 4. Stage 2 — Image2 (Flat Field + Photometric Calibration)
#
# Resample skipped — drizzle happens in Stage 3.

# %%
if run_image2:
    old_cal = glob.glob(f'{stage2}/*_cal.fits') + glob.glob(f'{stage2}/*_i2d.fits')
    for f in old_cal:
        os.remove(f)

    print(f'Running Stage 2 on {len(fixed_rate_files)} files...')
    for i, f in enumerate(fixed_rate_files):
        print(f'  [{i+1}/{len(fixed_rate_files)}] {os.path.basename(f)}')
        calwebb_image2.Image2Pipeline.call(
            f, steps={'resample': {'skip': True}},
            output_dir=stage2, save_results=True)
else:
    print('Skipping Stage 2 (run_image2 = False)')

cal_files = sorted(glob.glob(f'{stage2}/*_cal.fits'))
print(f'{len(cal_files)} cal files ready')
# Out:
# Running Stage 2 on 8 files...
#   [1/8] jw05952003001_04101_00001_mirimage_fixed_rate.fits
# 2026-03-28 04:20:36,211 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03
- stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-image2pipeline_0004.asdf
# 2026-03-28 04:20:42,044 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-03-28 04:20:42,045 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-03-28 04:20:42,045 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-03-28 04:20:42,046 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-03-28 04:20:42,046 - stpipe.step - INFO - PhotomStep instance created.
# 2026-03-28 04:20:42,047 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-28 04:20:42,117 - stpipe.step - INFO - Step Image2Pipeline running with args ('/Users/melyajou/SMC_GO5952/miri/F770W/stage1/jw05952003002_04101_00004_mirimage_fixed_rate.fits',).
# 2026-03-28 04:20:42,122 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/miri/F770W/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 2.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
# 2026-03-28 04:20:42,136 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw05952003002_04101_00004_mirimage_fixed_rate.fits' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-03-28 04:20:42,138 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits'.
# 2026-03-28 04:20:42,139 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-03-28 04:20:42,139 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-03-28 04:20:42,139 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-03-28 04:20:42,140 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-03-28 04:20:42,140 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-03-28 04:20:42,140 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2026-03-28 04:20:42,140 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-03-28 04:20:42,141 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2026-03-28 04:20:42,141 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0844.fits'.
# 2026-03-28 04:20:42,141 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-03-28 04:20:42,142 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-03-28 04:20:42,142 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-03-28 04:20:42,142 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-03-28 04:20:42,142 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-03-28 04:20:42,143 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-03-28 04:20:42,143 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-03-28 04:20:42,143 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-03-28 04:20:42,144 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-03-28 04:20:42,144 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-03-28 04:20:42,144 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-03-28 04:20:42,144 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-03-28 04:20:42,145 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-03-28 04:20:42,145 - jwst.pipeline.calwebb_image2 - INFO - Processing product /Users/melyajou/SMC_GO5952/miri/F770W/stage1/jw05952003002_04101_00004_mirimage_fixed
# 2026-03-28 04:20:42,145 - jwst.pipeline.calwebb_image2 - INFO - Working on input /Users/melyajou/SMC_GO5952/miri/F770W/stage1/jw05952003002_04101_00004_mirimage_fixed_rate.fits ...
#   [8/8] jw05952003002_04101_00004_mirimage_fixed_rate.fits
# 2026-03-28 04:20:42,247 - stpipe.step - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F770W/stage2/jw05952003002_04101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-28 04:20:42,306 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-03-28 04:20:42,335 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.360563213 -73.352592417 11.255588876 -73.361227039 11.285693164 -73.391440355 11.391290298 -73.383054868
# 2026-03-28 04:20:42,336 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  11.360563213 -73.352592417 11.255588876 -73.361227039 11.285693164 -73.391440355 11.391290298 -73.383054868
# 2026-03-28 04:20:42,337 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-03-28 04:20:42,350 - py.warnings - WARNING - /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/gwcs/wcs/_wcs.py:1803: LinAlgWarning: Failed to achieve requested SIP approximation accuracy.
#   fit_inv_poly_u, fit_inv_poly_v, max_inv_resid = fit_2D_poly(
#
# 2026-03-28 04:20:42,358 - stpipe.step - INFO - Step assign_wcs done
# 2026-03-28 04:20:42,429 - stpipe.step - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F770W/stage2/jw05952003002_04101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-28 04:20:42,454 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0844.fits
# 2026-03-28 04:20:42,454 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-03-28 04:20:42,455 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-03-28 04:20:42,455 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-03-28 04:20:42,500 - stpipe.step - INFO - Step flat_field done
# 2026-03-28 04:20:42,571 - stpipe.step - INFO - Step photom running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F770W/stage2/jw05952003002_04101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-28 04:20:42,579 - jwst.photom.photom_step - INFO - Using photom reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-03-28 04:20:42,579 - jwst.photom.photom_step - INFO - Using area reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits
# 2026-03-28 04:20:42,595 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-03-28 04:20:42,595 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-03-28 04:20:42,596 - jwst.photom.photom - INFO -  exp_type: MIR_IMAGE
# 2026-03-28 04:20:42,596 - jwst.photom.photom - INFO -  filter: F770W
# 2026-03-28 04:20:42,615 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-03-28 04:20:42,616 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-03-28 04:20:42,617 - jwst.photom.photom - INFO -  subarray: FULL
# 2026-03-28 04:20:42,617 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.996831
# 2026-03-28 04:20:42,618 - jwst.photom.photom - INFO - PHOTMJSR value: 0.256023
# 2026-03-28 04:20:42,630 - stpipe.step - INFO - Step photom done
# 2026-03-28 04:20:42,702 - stpipe.step - INFO - Step resample running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/miri/F770W/stage2/jw05952003002_04101_00004_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-28 04:20:42,703 - stpipe.step - INFO - Step skipped.
# 2026-03-28 04:20:42,704 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /Users/melyajou/SMC_GO5952/miri/F770W/stage1/jw05952003002_04101_00004_mirimage_fixed
# 2026-03-28 04:20:42,704 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-03-28 04:20:42,704 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1464.pmap
# 2026-03-28 04:20:42,780 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F770W/stage2/jw05952003002_04101_00004_mirimage_fixed_cal.fits
# 2026-03-28 04:20:42,781 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-03-28 04:20:42,781 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# 8 cal files ready

# %% [markdown]
# ## 5. Apply F560W WCS Shifts
#
# F560W (shortest wavelength) has the most point sources for tweakreg alignment.
# We reuse those shifts for all other MIRI filters.

# %%
# ─── Apply F560W shifts to cal files ─────────────────────
for f in glob.glob(f'{stage2}/*_wcs_cal.fits'):
    os.remove(f)

print(f'Applying F560W shifts:')
print(f'  T1: {TILE1_SHIFTS}')
print(f'  T2: {TILE2_SHIFTS}\n')

for cfile in cal_files:
    if TILE1_BASE in cfile:
        s, tile = TILE1_SHIFTS, 'T1'
    else:
        s, tile = TILE2_SHIFTS, 'T2'
    outfile = shift_wcs(cfile, s, "_wcs")
    print(f'  {tile}: {os.path.basename(outfile)}')

wcs_cal_files = sorted(glob.glob(f'{stage2}/*_wcs_cal.fits'))
print(f'\n{len(wcs_cal_files)} WCS-corrected cal files')
# Out:
# Applying F560W shifts:
#   T1: [-0.1674, -0.1364]
#   T2: [-0.1584, -0.1352]
#
#   T1: jw05952003001_04101_00001_mirimage_fixed_wcs_cal.fits
#   T1: jw05952003001_04101_00002_mirimage_fixed_wcs_cal.fits
#   T1: jw05952003001_04101_00003_mirimage_fixed_wcs_cal.fits
#   T1: jw05952003001_04101_00004_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_04101_00001_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_04101_00002_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_04101_00003_mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_04101_00004_mirimage_fixed_wcs_cal.fits
#
# 8 WCS-corrected cal files

# %% [markdown]
# ## 6. Lyot Flag + Stage 3 — Final Mosaic

# %%
# ─── Flag Lyot ───────────────────────────────────────────
wcs_cal_files = sorted(glob.glob(f'{stage2}/*_wcs_cal.fits'))
for f in wcs_cal_files:
    flag_lyot(f, lyot_row=LYOT_ROW, lyot_col=LYOT_COL)
print(f'Lyot flagged in {len(wcs_cal_files)} files')
# Out:
# Lyot flagged in 8 files

# %%
# ─── Stage 3 — Final mosaic ──────────────────────────────
if run_image3:
    old_s3 = glob.glob(f'{stage3}/*')
    for f in old_s3:
        os.remove(f)

    asn_name = f'miri_{FILT}_final'
    asn = asn_from_list.asn_from_list(
        wcs_cal_files, rule=DMS_Level3_Base, product_name=asn_name)
    asn_file = f'{stage3}/{asn_name}.json'
    with open(asn_file, 'w') as fp:
        name, serialized = asn.dump(format='json')
        fp.write(serialized)

    im3_dict = {
        'tweakreg':          {'skip': not TWEAKREG},
        'skymatch':          {'skymethod': 'match', 'subtract': SKY_SUBTRACT, 'skip': not SKYMATCH},
        'outlier_detection': {'skip': not OUTLIER_DET, 'save_results': True},
        'resample':          {'kernel': KERNEL, 'pixel_scale': PIXEL_SCALE, 'pixfrac': PIXFRAC},
    }

    print('Running Stage 3 (final mosaic)...')
    calwebb_image3.Image3Pipeline.call(
        asn_file, steps=im3_dict, output_dir=stage3, save_results=True)
    print('Stage 3 complete')
else:
    print('Skipping Stage 3 (run_image3 = False)')

mosaic = sorted(glob.glob(f'{stage3}/*_i2d.fits'))[0]
print(f'Mosaic: {mosaic}')
# Out:
# /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/jwst/associations/association.py:234: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-03-28 04:26:01,818 - stpipe.step - INFO - PARS-TWEAKREGSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-tweakregstep_0020.asdf
# 2026-03-28 04:26:01,827 - stpipe.step - INFO - PARS-OUTLIERDETECTIONSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-outlierdetectionstep_0096.asdf
# 2026-03-28 04:26:01,833 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03-28 04:26:01,838 - stpipe.step - INFO - PARS-SOURCECATALOGSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-sourcecatalogstep_0018.asdf
# 2026-03-28 04:26:01,847 - stpipe.step - INFO - Image3Pipeline instance created.
# 2026-03-28 04:26:01,848 - stpipe.step - INFO - AssignMTWcsStep instance created.
# 2026-03-28 04:26:01,849 - stpipe.step - INFO - TweakRegStep instance created.
# 2026-03-28 04:26:01,850 - stpipe.step - INFO - SkyMatchStep instance created.
# 2026-03-28 04:26:01,851 - stpipe.step - INFO - OutlierDetectionStep instance created.
# 2026-03-28 04:26:01,852 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-28 04:26:01,853 - stpipe.step - INFO - SourceCatalogStep instance created.
# 2026-03-28 04:26:01,941 - stpipe.step - INFO - Step Image3Pipeline running with args ('/Users/melyajou/SMC_GO5952/miri/F770W/stage3/miri_F770W_final.json',).
# Running Stage 3 (final mosaic)...
# 2026-03-28 04:26:01,952 - stpipe.step - INFO - Step Image3Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/miri/F770W/stage3
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   in_memory: True
#   steps:
#     assign_mtwcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: assign_mtwcs
#       search_output_file: True
#       input_dir: ''
#     tweakreg:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_catalogs: False
#       use_custom_catalogs: False
#       catalog_format: ecsv
#       catfile: ''
#       starfinder: iraf
#       snr_threshold: 10.0
#       kernel_fwhm: 2.19
#       bkg_boxsize: 400
#       minsep_fwhm: 0.0
#       sigma_radius: 1.5
#       sharplo: 0.5
#       sharphi: 2.0
#       roundlo: 0.0
#       roundhi: 0.2
#       brightest: 200
#       peakmax: None
#       npixels: 10
#       connectivity: '8'
#       nlevels: 32
#       contrast: 0.001
#       multithresh_mode: exponential
#       localbkg_width: 0
#       apermask_method: correct
#       kron_params: None
#       deblend: True
#       enforce_user_order: False
#       expand_refcat: False
#       minobj: 15
#       fitgeometry: rshift
#       nclip: 3
#       sigma: 3
#       searchrad: 1.0
#       use2dhist: True
#       separation: 1.0
#       tolerance: 0.7
#       xoffset: 0.0
#       yoffset: 0.0
#       abs_refcat: ''
#       save_abs_catalog: False
#       abs_minobj: 15
#       abs_fitgeometry: rshift
#       abs_nclip: 3
#       abs_sigma: 3.0
#       abs_searchrad: 6.0
#       abs_use2dhist: True
#       abs_separation: 1.0
#       abs_tolerance: 0.7
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       in_memory: True
#     skymatch:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       skymethod: match
#       match_down: True
#       subtract: False
#       skylist: None
#       stepsize: None
#       skystat: mode
#       dqbits: ~DO_NOT_USE+NON_SCIENCE
#       lower: None
#       upper: None
#       nclip: 5
#       lsigma: 4.0
#       usigma: 4.0
#       binwidth: 0.1
#       in_memory: True
#     outlier_detection:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: True
#       skip: False
#       suffix: None
#       search_output_file: False
#       input_dir: ''
#       weight_type: exptime
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       maskpt: 0.7
#       snr: 4.0 3.0
#       scale: 1.0 0.8
#       backg: 0.0
#       kernel_size: 7 7
#       threshold_percent: 99.8
#       rolling_window_width: 25
#       ifu_second_check: False
#       save_intermediate_results: False
#       resample_data: True
#       good_bits: ~DO_NOT_USE+NON_SCIENCE
#       in_memory: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: 0.11
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#     source_catalog:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: cat
#       search_output_file: True
#       input_dir: ''
#       aperture_ee1: 30
#       aperture_ee2: 50
#       aperture_ee3: 70
#       ci1_star_threshold: 2.0
#       ci2_star_threshold: 1.8
#       starfinder: segmentation
#       snr_threshold: 3.0
#       bkg_boxsize: 1000
#       kernel_fwhm: 2.27
#       minsep_fwhm: 0.0
#       sigma_radius: 1.5
#       sharplo: 0.5
#       sharphi: 2.0
#       roundlo: 0.0
#       roundhi: 0.2
#       brightest: 200
#       peakmax: None
#       npixels: 5
#       connectivity: '8'
#       nlevels: 32
#       contrast: 0.001
#       multithresh_mode: exponential
#       localbkg_width: 0
#       apermask_method: correct
#       kron_params: None
#       deblend: False
# 2026-03-28 04:26:02,103 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'miri_F770W_final.json' reftypes = ['abvegaoffset', 'apcorr']
# 2026-03-28 04:26:02,105 - stpipe.pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0002.asdf'.
# 2026-03-28 04:26:02,105 - stpipe.pipeline - INFO - Prefetch for APCORR reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_apcorr_0014.fits'.
# 2026-03-28 04:26:02,106 - jwst.pipeline.calwebb_image3 - INFO - Starting calwebb_image3 ...
# 2026-03-28 04:26:02,368 - stpipe.step - INFO - Step tweakreg running with args (<jwst.datamodels.library.ModelLibrary object at 0x130db28d0>,).
# 2026-03-28 04:26:02,369 - stpipe.step - INFO - Step skipped.
# 2026-03-28 04:26:03,033 - stpipe.step - INFO - Step skymatch running with args (<jwst.datamodels.library.ModelLibrary object at 0x130db28d0>,).
# 2026-03-28 04:26:03,034 - stpipe.step - INFO - Step skipped.
# 2026-03-28 04:26:03,138 - stpipe.step - INFO - Step outlier_detection running with args (<jwst.datamodels.library.ModelLibrary object at 0x130db28d0>,).
# 2026-03-28 04:26:03,138 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: imaging
# 2026-03-28 04:26:03,139 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-03-28 04:26:03,162 - jwst.resample.resample_utils - INFO - Pixel scale ratio (pscale_out/pscale_in): 1.0
# 2026-03-28 04:26:03,162 - jwst.resample.resample_utils - INFO - Computed output pixel scale: 0.11091996515584489 arcsec.
# 2026-03-28 04:26:03,171 - stcal.resample.resample - INFO - Output pixel scale: 0.11091996515584489 arcsec.
# 2026-03-28 04:26:03,171 - stcal.resample.resample - INFO - Driz parameter kernel: square
# 2026-03-28 04:26:03,172 - stcal.resample.resample - INFO - Driz parameter pixfrac: 1.0
# 2026-03-28 04:26:03,172 - stcal.resample.resample - INFO - Driz parameter fillval: NAN
# 2026-03-28 04:26:03,172 - stcal.resample.resample - INFO - Driz parameter weight_type: exptime
# 2026-03-28 04:26:03,174 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:26:03,460 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:03,599 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-28 04:26:03,628 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:26:03,885 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:04,022 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-28 04:26:04,051 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:26:04,311 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:04,448 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-28 04:26:04,476 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:26:04,739 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:04,877 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-28 04:26:04,906 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:26:05,174 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:05,311 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-28 04:26:05,342 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:26:05,611 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:05,748 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-28 04:26:05,778 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:26:06,041 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:06,179 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-28 04:26:06,210 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-28 04:26:06,474 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:06,612 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-28 04:26:07,647 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:26:07,685 - jwst.outlier_detection.utils - INFO - 3889 pixels marked as outliers
# 2026-03-28 04:26:08,002 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:26:08,038 - jwst.outlier_detection.utils - INFO - 4630 pixels marked as outliers
# 2026-03-28 04:26:08,353 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:26:08,392 - jwst.outlier_detection.utils - INFO - 3161 pixels marked as outliers
# 2026-03-28 04:26:08,707 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:26:08,743 - jwst.outlier_detection.utils - INFO - 3813 pixels marked as outliers
# 2026-03-28 04:26:09,059 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:26:09,095 - jwst.outlier_detection.utils - INFO - 2346 pixels marked as outliers
# 2026-03-28 04:26:09,408 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:26:09,443 - jwst.outlier_detection.utils - INFO - 2920 pixels marked as outliers
# 2026-03-28 04:26:09,755 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:26:09,791 - jwst.outlier_detection.utils - INFO - 2879 pixels marked as outliers
# 2026-03-28 04:26:10,116 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-28 04:26:10,151 - jwst.outlier_detection.utils - INFO - 4652 pixels marked as outliers
# 2026-03-28 04:26:10,252 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F770W/stage3/jw05952003001_04101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:26:10,331 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F770W/stage3/jw05952003001_04101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:26:10,410 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F770W/stage3/jw05952003001_04101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:26:10,488 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F770W/stage3/jw05952003001_04101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:26:10,567 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F770W/stage3/jw05952003002_04101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:26:10,646 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F770W/stage3/jw05952003002_04101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:26:10,729 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F770W/stage3/jw05952003002_04101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:26:10,809 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F770W/stage3/jw05952003002_04101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-28 04:26:10,810 - stpipe.step - INFO - Step outlier_detection done
# 2026-03-28 04:26:10,912 - stpipe.step - INFO - Step resample running with args (<jwst.datamodels.library.ModelLibrary object at 0x130db28d0>,).
# 2026-03-28 04:26:10,998 - jwst.resample.resample_utils - INFO - Output pixel scale: 0.10999999999999999 arcsec.
# 2026-03-28 04:26:10,999 - jwst.resample.resample_utils - INFO - Computed pixel scale ratio (pscale_out/pscale_in): 0.9970271327537857.
# 2026-03-28 04:26:11,006 - stcal.resample.resample - INFO - Output pixel scale: 0.10999999999999999 arcsec.
# 2026-03-28 04:26:11,007 - stcal.resample.resample - INFO - Driz parameter kernel: square
# 2026-03-28 04:26:11,007 - stcal.resample.resample - INFO - Driz parameter pixfrac: 1.0
# 2026-03-28 04:26:11,008 - stcal.resample.resample - INFO - Driz parameter fillval: NAN
# 2026-03-28 04:26:11,008 - stcal.resample.resample - INFO - Driz parameter weight_type: exptime
# 2026-03-28 04:26:11,019 - jwst.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:11,297 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:11,399 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:11,500 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:11,599 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:12,067 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:12,172 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:12,274 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:12,374 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:12,800 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:12,903 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:13,003 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:13,104 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:13,519 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:13,622 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:13,722 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:13,822 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:14,235 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:14,338 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:14,439 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:14,539 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:14,950 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:15,053 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:15,153 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:15,253 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:15,667 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:15,771 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:15,967 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:16,069 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:16,485 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-28 04:26:16,588 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:16,688 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:16,789 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-28 04:26:17,091 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359618 -73.347624895 11.249861643 -73.357489349 11.302023308 -73.410237600 11.423866182 -73.400342685
# 2026-03-28 04:26:17,233 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F770W/stage3/miri_F770W_final_i2d.fits
# 2026-03-28 04:26:17,233 - stpipe.step - INFO - Step resample done
# 2026-03-28 04:26:17,335 - stpipe.step - INFO - Step source_catalog running with args (<ImageModel(1184, 1794) from miri_F770W_final_i2d.fits>,).
# 2026-03-28 04:26:17,342 - jwst.source_catalog.source_catalog_step - INFO - Using APCORR reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_apcorr_0014.fits
# 2026-03-28 04:26:17,345 - jwst.source_catalog.source_catalog_step - INFO - Using ABVEGAOFFSET reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0002.asdf
# 2026-03-28 04:26:17,346 - jwst.source_catalog.reference_data - INFO - Instrument: MIRI
# 2026-03-28 04:26:17,346 - jwst.source_catalog.reference_data - INFO - Detector: MIRIMAGE
# 2026-03-28 04:26:17,347 - jwst.source_catalog.reference_data - INFO - Filter: F770W
# 2026-03-28 04:26:17,347 - jwst.source_catalog.reference_data - INFO - Subarray: FULL
# 2026-03-28 04:26:17,375 - jwst.source_catalog.reference_data - INFO - AB to Vega magnitude offset 4.38398
# 2026-03-28 04:26:17,515 - jwst.tweakreg.tweakreg_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1184, 1794).
# 2026-03-28 04:26:18,179 - jwst.source_catalog.source_catalog_step - INFO - Wrote source catalog: /Users/melyajou/SMC_GO5952/miri/F770W/stage3/miri_F770W_final_cat.ecsv
# 2026-03-28 04:26:18,245 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/miri/F770W/stage3/miri_F770W_final_segm.fits
# 2026-03-28 04:26:18,246 - jwst.source_catalog.source_catalog_step - INFO - Wrote segmentation map: miri_F770W_final_segm.fits
# 2026-03-28 04:26:18,247 - stpipe.step - INFO - Step source_catalog done
# 2026-03-28 04:26:18,250 - stpipe.step - INFO - Step Image3Pipeline done
# 2026-03-28 04:26:18,251 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# Stage 3 complete
# Mosaic: /Users/melyajou/SMC_GO5952/miri/F770W/stage3/miri_F770W_final_i2d.fits

# %%
final_sci = load_mosaic(mosaic)
m_ours = get_stats(final_sci)
plot_mosaic(final_sci, f'Final — {FILT}', f'{FILT}_final.png',
            fig_dir=fig_dir, stats_txt=stats_label(*m_ours))

# %% [markdown]
# ## 7. Comparison with MAST

# %%
mast_i2d = sorted(glob.glob(f'{mast_dir}/*_i2d.fits'))
if mast_i2d:
    mast_sci = load_mosaic(mast_i2d[0])
    m_mast = get_stats(mast_sci)

    plot_comparison(final_sci, mast_sci,
                    'This work', 'MAST standard',
                    f'{FILT}_comparison.png', fig_dir=fig_dir,
                    stats1=stats_label(*m_ours), stats2=stats_label(*m_mast))

    print(f'This work: median = {m_ours[0]:.3f}, σ = {m_ours[1]:.3f} MJy/sr')
    print(f'MAST:      median = {m_mast[0]:.3f}, σ = {m_mast[1]:.3f} MJy/sr')
else:
    print('No MAST reference found')
# Out:
# This work: median = 4.957, σ = 0.579 MJy/sr
# MAST:      median = 4.686, σ = 0.619 MJy/sr

# %% [markdown]
# ## 8. Summary

# %%
line = '=' * 50
tweakreg_str = 'ON' if TWEAKREG else 'OFF'
skymatch_str = 'ON' if SKYMATCH else 'OFF'
skysub_str   = 'ON' if SKY_SUBTRACT else 'OFF'
outlier_str  = 'ON' if OUTLIER_DET else 'OFF'

print(line)
print(f'  {TARGET} ({PROGRAM}) — {FILT}')
print(line)
print()
if 'm_ours' in dir():
    print(f'  Result:')
    print(f'    median = {m_ours[0]:.3f} MJy/sr')
    print(f'    σ = {m_ours[1]:.3f} MJy/sr')
print()
print(f'  WCS shifts (from F560W):')
print(f'    Tile 1: {TILE1_SHIFTS}')
print(f'    Tile 2: {TILE2_SHIFTS}')
print()
print(f'  Stage 1:')
print(f'    IPC:              {"SKIP" if IPC_SKIP else "ON"}')
print(f'    Jump threshold:   {JUMP_THRESHOLD}σ')
print()
print(f'  Lyot flag: row>{LYOT_ROW}, col<{LYOT_COL}')
print()
print(f'  Stage 3:')
print(f'    Pixel scale:      {PIXEL_SCALE} arcsec/pix')
print(f'    Pixfrac:          {PIXFRAC}')
print(f'    Kernel:           {KERNEL}')
print(f'    Tweakreg:         {tweakreg_str}')
print(f'    Skymatch:         {skymatch_str}')
print(f'    Sky subtract:     {skysub_str}')
print(f'    Outlier det:      {outlier_str}')
print(line)
# Out:
# ==================================================
#   SMC-SW-Bar-3 (GO-5952) — F770W
# ==================================================
#
#   Result:
#     median = 4.957 MJy/sr
#     σ = 0.579 MJy/sr
#
#   WCS shifts (from F560W):
#     Tile 1: [-0.1674, -0.1364]
#     Tile 2: [-0.1584, -0.1352]
#
#   Stage 1:
#     IPC:              SKIP
#     Jump threshold:   5.0σ
#
#   Lyot flag: row>700, col<310
#
#   Stage 3:
#     Pixel scale:      0.11 arcsec/pix
#     Pixfrac:          1.0
#     Kernel:           square
#     Tweakreg:         OFF
#     Skymatch:         OFF
#     Sky subtract:     OFF
#     Outlier det:      ON
# ==================================================
