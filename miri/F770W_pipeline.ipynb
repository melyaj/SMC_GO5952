# %% [markdown]
# # F770W JWST/MIRI Imaging Pipeline — SMC-SW-Bar-3 (GO-5952)
#
# Custom data reduction for JWST/MIRI F770W (7.7 µm) imaging.
#
# WCS alignment uses shifts measured from F560W (see `F560W_pipeline.ipynb`).
#
# **Pipeline:** Stage 1 → fix_rateints → Stage 2 → apply F560W shifts → Lyot flag → Stage 3

# %% [markdown]
# ## 1. Configuration

# %%
# ═══════════════════════════════════════════════════════════
# CONFIGURATION
# ═══════════════════════════════════════════════════════════

# ─── Target ───────────────────────────────────────────────
FILT           = 'F770W'
TARGET         = 'SMC-SW-Bar-3'
PROGRAM        = 'GO-5952'

# ─── Paths ────────────────────────────────────────────────
BASE_DIR       = '/Users/melyajou/SMC_GO5952/data/miri'
TILE1_BASE     = 'jw05952003001'
TILE2_BASE     = 'jw05952003002'

# ─── WCS shifts (from F560W tweakreg) ────────────────────
TILE1_SHIFTS   = [-0.1674, -0.1364]
TILE2_SHIFTS   = [-0.1584, -0.1352]

# ─── Lyot coronagraph artifact ───────────────────────────
LYOT_ROW       = 700
LYOT_COL       = 310

# ─── Stage 1 options ─────────────────────────────────────
IPC_SKIP       = True       # skip IPC correction (Karl's practice)
JUMP_THRESHOLD = 5.0        # sigma for jump detection (MAST uses 4.0)

# ─── Run flags ────────────────────────────────────────────
run_detector1  = False       # Stage 1: detector1 + fix_rateints
run_image2     = True       # Stage 2: image2 calibration
run_image3     = True       # Stage 3: final mosaic

# ─── Stage 3 options ─────────────────────────────────────
TWEAKREG       = False      # skip — F560W shifts applied above
SKYMATCH       = False       # match sky levels between exposures
SKY_SUBTRACT   = False      # offset only, do not subtract
OUTLIER_DET    = True
PIXEL_SCALE    = 0.11       # arcsec/pix
PIXFRAC        = 1.0
KERNEL         = 'square'

# ─── Figures ─────────────────────────────────────────────
CMAP           = 'afmhot'
FIG_DPI        = 200

# %% [markdown]
# ## 2. Setup

# %%
import os, sys, glob, warnings, time
import numpy as np
import matplotlib.pyplot as plt
import logging

logging.getLogger('stpipe').setLevel(logging.WARNING)
logging.getLogger('CRDS').setLevel(logging.WARNING)

os.environ['CRDS_PATH']       = '/Users/melyajou/SMC_GO5952/crds_cache'
os.environ['CRDS_SERVER_URL'] = 'https://jwst-crds.stsci.edu'

from astropy.io import fits
from astropy.stats import sigma_clipped_stats, sigma_clip
from jwst import datamodels
from jwst.datamodels import dqflags
from jwst.pipeline import calwebb_detector1, calwebb_image2, calwebb_image3
from jwst.associations import asn_from_list
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

sys.path.insert(0, '..')
from pipeline_utils import *

# Directories
stage0   = f'{BASE_DIR}/{FILT}/stage0'
stage1   = f'{BASE_DIR}/{FILT}/stage1'
stage2   = f'{BASE_DIR}/{FILT}/stage2'
stage3   = f'{BASE_DIR}/{FILT}/stage3'
fig_dir  = f'{BASE_DIR}/{FILT}/figures'
mast_dir = f'{BASE_DIR}/{FILT}/mast_reference'

for d in [stage0, stage1, stage2, stage3, fig_dir]:
    os.makedirs(d, exist_ok=True)

print(f'{TARGET} ({PROGRAM}) — {FILT}')
# Out:
# SMC-SW-Bar-3 (GO-5952) — F770W

# %% [markdown]
# ## 3. Stage 1 — Detector1 + fix_rateints

# %%
uncal_files = sorted(glob.glob(f'{stage0}/*_uncal.fits'))
print(f'{len(uncal_files)} uncal files')

if run_detector1:
    fixed_rate_files = run_stage1(uncal_files, stage1, IPC_SKIP, JUMP_THRESHOLD, TILE1_BASE)
else:
    print('Skipping Stage 1 (run_detector1 = False)')
    fixed_rate_files = sorted(glob.glob(f'{stage1}/*_fixed_rate.fits'))
    print(f'{len(fixed_rate_files)} fixed_rate files ready')
# Out:
# 8 uncal files
# Skipping Stage 1 (run_detector1 = False)
# 8 fixed_rate files ready

# %% [markdown]
# ## 4. Stage 2 — Image2

# %%
if run_image2:
    cal_files = run_stage2(fixed_rate_files, stage2)
else:
    print('Skipping Stage 2 (run_image2 = False)')
    cal_files = sorted(glob.glob(f'{stage2}/*_cal.fits'))
    print(f'{len(cal_files)} cal files ready')
# Out:
# Running Stage 2 on 8 files...
#   [1/8] jw05952003001_04101_00001_mirimage_fixed_rate.fits
# 2026-03-30 15:07:50,647 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03-30 15:07:50,655 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-image2pipeline_0004.asdf
# 2026-03-30 15:07:50,662 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-03-30 15:07:50,663 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-03-30 15:07:50,663 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-03-30 15:07:50,664 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-03-30 15:07:50,664 - stpipe.step - INFO - PhotomStep instance created.
# 2026-03-30 15:07:50,665 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-30 15:07:50,734 - stpipe.step - INFO - Step Image2Pipeline running with args ('/Users/melyajou/SMC_GO5952/data/miri/F770W/stage1/jw05952003001_04101_00001_mirimage_fixed_rate.fits',).
# 2026-03-30 15:07:50,740 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/data/miri/F770W/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 2.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
# 2026-03-30 15:07:50,761 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'jw05952003001_04101_00001_mirimage_fixed_rate.fits' reftypes = ['area', 'bkg', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange']
# 2026-03-30 15:07:50,763 - stpipe.pipeline - INFO - Prefetch for AREA reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits'.
# 2026-03-30 15:07:50,763 - stpipe.pipeline - INFO - Prefetch for BKG reference file is 'N/A'.
# 2026-03-30 15:07:50,763 - stpipe.pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2026-03-30 15:07:50,764 - stpipe.pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2026-03-30 15:07:50,764 - stpipe.pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2026-03-30 15:07:50,764 - stpipe.pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2026-03-30 15:07:50,764 - stpipe.pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2026-03-30 15:07:50,765 - stpipe.pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2026-03-30 15:07:50,765 - stpipe.pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf'.
# 2026-03-30 15:07:50,766 - stpipe.pipeline - INFO - Prefetch for FLAT reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0844.fits'.
# 2026-03-30 15:07:50,766 - stpipe.pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2026-03-30 15:07:50,766 - stpipe.pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2026-03-30 15:07:50,766 - stpipe.pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2026-03-30 15:07:50,767 - stpipe.pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2026-03-30 15:07:50,767 - stpipe.pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2026-03-30 15:07:50,767 - stpipe.pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2026-03-30 15:07:50,768 - stpipe.pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2026-03-30 15:07:50,768 - stpipe.pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits'.
# 2026-03-30 15:07:50,768 - stpipe.pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2026-03-30 15:07:50,769 - stpipe.pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2026-03-30 15:07:50,769 - stpipe.pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2026-03-30 15:07:50,770 - stpipe.pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2026-03-30 15:07:50,770 - jwst.pipeline.calwebb_image2 - INFO - Starting calwebb_image2 ...
# 2026-03-30 15:07:50,770 - jwst.pipeline.calwebb_image2 - INFO - Processing product /Users/melyajou/SMC_GO5952/data/miri/F770W/stage1/jw05952003001_04101_00001_mirimage_fixed
# 2026-03-30 15:07:50,771 - jwst.pipeline.calwebb_image2 - INFO - Working on input /Users/melyajou/SMC_GO5952/data/miri/F770W/stage1/jw05952003001_04101_00001_mirimage_fixed_rate.fits ...
# 2026-03-30 15:07:50,871 - stpipe.step - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/data/miri/F770W/stage2/jw05952003001_04101_00001_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:07:50,980 - jwst.assign_wcs.miri - INFO - Created a MIRI mir_image pipeline with references {'distortion': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2026-03-30 15:07:51,013 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.372524948 -73.366786242 11.267469077 -73.375426455 11.297617993 -73.405638190 11.403297467 -73.397247065
# 2026-03-30 15:07:51,014 - jwst.assign_wcs.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  11.372524948 -73.366786242 11.267469077 -73.375426455 11.297617993 -73.405638190 11.403297467 -73.397247065
# 2026-03-30 15:07:51,015 - jwst.assign_wcs.assign_wcs - INFO - COMPLETED assign_wcs
# 2026-03-30 15:07:51,031 - py.warnings - WARNING - /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/gwcs/wcs/_wcs.py:1803: LinAlgWarning: Failed to achieve requested SIP approximation accuracy.
#   fit_inv_poly_u, fit_inv_poly_v, max_inv_resid = fit_2D_poly(
#
# 2026-03-30 15:07:51,148 - stpipe.step - INFO - Step assign_wcs done
# 2026-03-30 15:07:51,226 - stpipe.step - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/data/miri/F770W/stage2/jw05952003001_04101_00001_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:07:51,263 - jwst.flatfield.flat_field_step - INFO - Using FLAT reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_flat_0844.fits
# 2026-03-30 15:07:51,263 - jwst.flatfield.flat_field_step - INFO - No reference found for type FFLAT
# 2026-03-30 15:07:51,264 - jwst.flatfield.flat_field_step - INFO - No reference found for type SFLAT
# 2026-03-30 15:07:51,264 - jwst.flatfield.flat_field_step - INFO - No reference found for type DFLAT
# 2026-03-30 15:07:51,314 - stpipe.step - INFO - Step flat_field done
# 2026-03-30 15:07:51,384 - stpipe.step - INFO - Step photom running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/data/miri/F770W/stage2/jw05952003001_04101_00001_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:07:51,394 - jwst.photom.photom_step - INFO - Using photom reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_photom_0230.fits
# 2026-03-30 15:07:51,394 - jwst.photom.photom_step - INFO - Using area reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_area_0006.fits
# 2026-03-30 15:07:51,410 - jwst.photom.photom - INFO - Using instrument: MIRI
# 2026-03-30 15:07:51,410 - jwst.photom.photom - INFO -  detector: MIRIMAGE
# 2026-03-30 15:07:51,411 - jwst.photom.photom - INFO -  exp_type: MIR_IMAGE
# 2026-03-30 15:07:51,411 - jwst.photom.photom - INFO -  filter: F770W
# 2026-03-30 15:07:51,436 - jwst.photom.photom - INFO - Pixel area map copied to output.
# 2026-03-30 15:07:51,437 - jwst.photom.photom - INFO - Values for PIXAR_SR and PIXAR_A2 obtained from AREA reference file.
# 2026-03-30 15:07:51,437 - jwst.photom.photom - INFO -  subarray: FULL
# 2026-03-30 15:07:51,438 - jwst.photom.photom - INFO - Multiplicative time dependence correction is 0.996837
# 2026-03-30 15:07:51,438 - jwst.photom.photom - INFO - PHOTMJSR value: 0.256021
# 2026-03-30 15:07:51,451 - stpipe.step - INFO - Step photom done
# 2026-03-30 15:07:51,521 - stpipe.step - INFO - Step resample running with args (<ImageModel(1024, 1032) from /Users/melyajou/SMC_GO5952/data/miri/F770W/stage2/jw05952003001_04101_00001_mirimage_fixed_image2pipeline.fits>,).
# 2026-03-30 15:07:51,521 - stpipe.step - INFO - Step skipped.
# 2026-03-30 15:07:51,522 - jwst.pipeline.calwebb_image2 - INFO - Finished processing product /Users/melyajou/SMC_GO5952/data/miri/F770W/stage1/jw05952003001_04101_00001_mirimage_fixed
# 2026-03-30 15:07:51,523 - jwst.pipeline.calwebb_image2 - INFO - ... ending calwebb_image2
# 2026-03-30 15:07:51,523 - jwst.stpipe.core - INFO - Results used CRDS context: jwst_1464.pmap
# 2026-03-30 15:07:51,602 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/data/miri/F770W/stage2/jw05952003001_04101_00001_mirimage_fixed_cal.fits
# 2026-03-30 15:07:51,603 - stpipe.step - INFO - Step Image2Pipeline done
# 2026-03-30 15:07:51,603 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# 2026-03-30 15:07:51,632 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03-30 15:07:51,636 - stpipe.pipeline - INFO - PARS-IMAGE2PIPELINE parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-image2pipeline_0004.asdf
# 2026-03-30 15:07:51,642 - stpipe.step - INFO - Image2Pipeline instance created.
# 2026-03-30 15:07:51,643 - stpipe.step - INFO - BackgroundStep instance created.
# 2026-03-30 15:07:51,644 - stpipe.step - INFO - AssignWcsStep instance created.
# 2026-03-30 15:07:51,644 - stpipe.step - INFO - FlatFieldStep instance created.
# 2026-03-30 15:07:51,645 - stpipe.step - INFO - PhotomStep instance created.
# 2026-03-30 15:07:51,645 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-30 15:07:51,717 - stpipe.step - INFO - Step Image2Pipeline running with args ('/Users/melyajou/SMC_GO5952/data/miri/F770W/stage1/jw05952003001_04101_00002_mirimage_fixed_rate.fits',).
# 2026-03-30 15:07:51,722 - stpipe.step - INFO - Step Image2Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/data/miri/F770W/stage2
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   save_bsub: False
#   steps:
#     bkg_subtract:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       bkg_list: None
#       save_combined_background: False
#       sigma: 2.0
#       maxiters: None
#       soss_source_percentile: 35.0
#       soss_bkg_percentile: None
#       wfss_mmag_extract: None
#       wfss_maxiter: 5
#       wfss_rms_stop: 0.0
#       wfss_outlier_percent: 1.0
#     assign_wcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       slit_y_low: -0.55
#       slit_y_high: 0.55
#       nrs_ifu_slice_wcs: False
#     flat_field:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_interpolated_flat: False
#       user_supplied_flat: None
#       inverse: False
#     photom:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       inverse: False
#       source_type: None
#       apply_time_correction: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: None
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
# 2026-03
mirimage_fixed_wcs_cal.fits
#   T2: jw05952003002_04101_00004_mirimage_fixed_wcs_cal.fits
#
# 8 WCS-corrected cal files

# %% [markdown]
# ## 6. Lyot Flag + Stage 3 — Final Mosaic

# %%
for f in wcs_cal_files:
    flag_lyot(f, lyot_row=LYOT_ROW, lyot_col=LYOT_COL)
print(f'Lyot flagged in {len(wcs_cal_files)} files')
# Out:
# Lyot flagged in 8 files

# %%
if run_image3:
    mosaic = run_stage3(
        wcs_cal_files, f'miri_{FILT}_final', stage3,
        tweakreg=TWEAKREG, skymatch=SKYMATCH, sky_subtract=SKY_SUBTRACT,
        outlier_det=OUTLIER_DET, pixel_scale=PIXEL_SCALE,
        pixfrac=PIXFRAC, kernel=KERNEL)
else:
    print('Skipping Stage 3 (run_image3 = False)')
    mosaic = sorted(glob.glob(f'{stage3}/*_i2d.fits'))[0]

print(f'Mosaic: {mosaic}')
# Out:
# /Users/melyajou/miniforge3/envs/jwst/lib/python3.11/site-packages/jwst/associations/association.py:234: UserWarning: Input association file contains path information; note that this can complicate usage and/or sharing of such files.
#   warnings.warn(err_str, UserWarning, stacklevel=1)
# 2026-03-30 15:08:00,709 - stpipe.step - INFO - PARS-TWEAKREGSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-tweakregstep_0020.asdf
# 2026-03-30 15:08:00,717 - stpipe.step - INFO - PARS-OUTLIERDETECTIONSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-outlierdetectionstep_0096.asdf
# 2026-03-30 15:08:00,722 - stpipe.step - INFO - PARS-RESAMPLESTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-resamplestep_0001.asdf
# 2026-03-30 15:08:00,727 - stpipe.step - INFO - PARS-SOURCECATALOGSTEP parameters found: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_pars-sourcecatalogstep_0018.asdf
# 2026-03-30 15:08:00,736 - stpipe.step - INFO - Image3Pipeline instance created.
# 2026-03-30 15:08:00,736 - stpipe.step - INFO - AssignMTWcsStep instance created.
# 2026-03-30 15:08:00,738 - stpipe.step - INFO - TweakRegStep instance created.
# 2026-03-30 15:08:00,738 - stpipe.step - INFO - SkyMatchStep instance created.
# 2026-03-30 15:08:00,739 - stpipe.step - INFO - OutlierDetectionStep instance created.
# 2026-03-30 15:08:00,740 - stpipe.step - INFO - ResampleStep instance created.
# 2026-03-30 15:08:00,741 - stpipe.step - INFO - SourceCatalogStep instance created.
# 2026-03-30 15:08:00,823 - stpipe.step - INFO - Step Image3Pipeline running with args ('/Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/miri_F770W_final.json',).
# 2026-03-30 15:08:00,832 - stpipe.step - INFO - Step Image3Pipeline parameters are:
#   pre_hooks: []
#   post_hooks: []
#   output_file: None
#   output_dir: /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3
#   output_ext: .fits
#   output_use_model: False
#   output_use_index: True
#   save_results: True
#   skip: False
#   suffix: None
#   search_output_file: True
#   input_dir: ''
#   in_memory: True
#   steps:
#     assign_mtwcs:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: assign_mtwcs
#       search_output_file: True
#       input_dir: ''
#     tweakreg:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: True
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       save_catalogs: False
#       use_custom_catalogs: False
#       catalog_format: ecsv
#       catfile: ''
#       starfinder: iraf
#       snr_threshold: 10.0
#       kernel_fwhm: 2.19
#       bkg_boxsize: 400
#       minsep_fwhm: 0.0
#       sigma_radius: 1.5
#       sharplo: 0.5
#       sharphi: 2.0
#       roundlo: 0.0
#       roundhi: 0.2
#       brightest: 200
#       peakmax: None
#       npixels: 10
#       connectivity: '8'
#       nlevels: 32
#       contrast: 0.001
#       multithresh_mode: exponential
#       localbkg_width: 0
#       apermask_method: correct
#       kron_params: None
#       deblend: True
#       enforce_user_order: False
#       expand_refcat: False
#       minobj: 15
#       fitgeometry: rshift
#       nclip: 3
#       sigma: 3
#       searchrad: 1.0
#       use2dhist: True
#       separation: 1.0
#       tolerance: 0.7
#       xoffset: 0.0
#       yoffset: 0.0
#       abs_refcat: ''
#       save_abs_catalog: False
#       abs_minobj: 15
#       abs_fitgeometry: rshift
#       abs_nclip: 3
#       abs_sigma: 3.0
#       abs_searchrad: 6.0
#       abs_use2dhist: True
#       abs_separation: 1.0
#       abs_tolerance: 0.7
#       sip_approx: True
#       sip_max_pix_error: 0.01
#       sip_degree: None
#       sip_max_inv_pix_error: 0.01
#       sip_inv_degree: None
#       sip_npoints: 12
#       in_memory: True
#     skymatch:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: True
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       skymethod: match
#       match_down: True
#       subtract: False
#       skylist: None
#       stepsize: None
#       skystat: mode
#       dqbits: ~DO_NOT_USE+NON_SCIENCE
#       lower: None
#       upper: None
#       nclip: 5
#       lsigma: 4.0
#       usigma: 4.0
#       binwidth: 0.1
#       in_memory: True
#     outlier_detection:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: False
#       input_dir: ''
#       weight_type: exptime
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       maskpt: 0.7
#       snr: 4.0 3.0
#       scale: 1.0 0.8
#       backg: 0.0
#       kernel_size: 7 7
#       threshold_percent: 99.8
#       rolling_window_width: 25
#       ifu_second_check: False
#       save_intermediate_results: False
#       resample_data: True
#       good_bits: ~DO_NOT_USE+NON_SCIENCE
#       in_memory: True
#     resample:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: None
#       search_output_file: True
#       input_dir: ''
#       pixfrac: 1.0
#       kernel: square
#       fillval: NAN
#       weight_type: exptime
#       output_shape: None
#       crpix: None
#       crval: None
#       rotation: None
#       pixel_scale_ratio: 1.0
#       pixel_scale: 0.11
#       output_wcs: ''
#       single: False
#       blendheaders: True
#       in_memory: True
#       enable_ctx: True
#       enable_err: True
#       report_var: True
#     source_catalog:
#       pre_hooks: []
#       post_hooks: []
#       output_file: None
#       output_dir: None
#       output_ext: .fits
#       output_use_model: False
#       output_use_index: True
#       save_results: False
#       skip: False
#       suffix: cat
#       search_output_file: True
#       input_dir: ''
#       aperture_ee1: 30
#       aperture_ee2: 50
#       aperture_ee3: 70
#       ci1_star_threshold: 2.0
#       ci2_star_threshold: 1.8
#       starfinder: segmentation
#       snr_threshold: 3.0
#       bkg_boxsize: 1000
#       kernel_fwhm: 2.27
#       minsep_fwhm: 0.0
#       sigma_radius: 1.5
#       sharplo: 0.5
#       sharphi: 2.0
#       roundlo: 0.0
#       roundhi: 0.2
#       brightest: 200
#       peakmax: None
#       npixels: 5
#       connectivity: '8'
#       nlevels: 32
#       contrast: 0.001
#       multithresh_mode: exponential
#       localbkg_width: 0
#       apermask_method: correct
#       kron_params: None
#       deblend: False
# 2026-03-30 15:08:00,887 - stpipe.pipeline - INFO - Prefetching reference files for dataset: 'miri_F770W_final.json' reftypes = ['abvegaoffset', 'apcorr']
# 2026-03-30 15:08:00,889 - stpipe.pipeline - INFO - Prefetch for ABVEGAOFFSET reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0002.asdf'.
# 2026-03-30 15:08:00,889 - stpipe.pipeline - INFO - Prefetch for APCORR reference file is '/Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_apcorr_0014.fits'.
# 2026-03-30 15:08:00,890 - jwst.pipeline.calwebb_image3 - INFO - Starting calwebb_image3 ...
# 2026-03-30 15:08:01,152 - stpipe.step - INFO - Step tweakreg running with args (<jwst.datamodels.library.ModelLibrary object at 0x12e8df650>,).
# 2026-03-30 15:08:01,153 - stpipe.step - INFO - Step skipped.
# 2026-03-30 15:08:01,846 - stpipe.step - INFO - Step skymatch running with args (<jwst.datamodels.library.ModelLibrary object at 0x12e8df650>,).
# 2026-03-30 15:08:01,846 - stpipe.step - INFO - Step skipped.
# 2026-03-30 15:08:01,954 - stpipe.step - INFO - Step outlier_detection running with args (<jwst.datamodels.library.ModelLibrary object at 0x12e8df650>,).
# 2026-03-30 15:08:01,954 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection mode: imaging
# 2026-03-30 15:08:01,955 - jwst.outlier_detection.outlier_detection_step - INFO - Outlier Detection asn_id: a3001
# 2026-03-30 15:08:01,983 - jwst.resample.resample_utils - INFO - Pixel scale ratio (pscale_out/pscale_in): 1.0
# 2026-03-30 15:08:01,983 - jwst.resample.resample_utils - INFO - Computed output pixel scale: 0.11091996515584489 arcsec.
# 2026-03-30 15:08:01,992 - stcal.resample.resample - INFO - Output pixel scale: 0.11091996515584489 arcsec.
# 2026-03-30 15:08:01,993 - stcal.resample.resample - INFO - Driz parameter kernel: square
# 2026-03-30 15:08:01,993 - stcal.resample.resample - INFO - Driz parameter pixfrac: 1.0
# 2026-03-30 15:08:01,993 - stcal.resample.resample - INFO - Driz parameter fillval: NAN
# 2026-03-30 15:08:01,994 - stcal.resample.resample - INFO - Driz parameter weight_type: exptime
# 2026-03-30 15:08:01,996 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:08:02,308 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:02,450 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-30 15:08:02,481 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:08:02,762 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:02,903 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-30 15:08:02,934 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:08:03,216 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:03,356 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-30 15:08:03,387 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:08:03,699 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:03,844 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-30 15:08:03,876 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:08:04,211 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:04,351 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-30 15:08:04,381 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:08:04,664 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:04,802 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-30 15:08:04,835 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:08:05,130 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:05,270 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-30 15:08:05,302 - jwst.resample.resample - INFO - 1 exposures to drizzle together
# 2026-03-30 15:08:05,589 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:05,728 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359925 -73.347624737 11.249777049 -73.357496056 11.301934925 -73.410240751 11.423862917 -73.400338953
# 2026-03-30 15:08:06,790 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:08:06,826 - jwst.outlier_detection.utils - INFO - 3889 pixels marked as outliers
# 2026-03-30 15:08:07,165 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:08:07,200 - jwst.outlier_detection.utils - INFO - 4630 pixels marked as outliers
# 2026-03-30 15:08:07,530 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:08:07,568 - jwst.outlier_detection.utils - INFO - 3161 pixels marked as outliers
# 2026-03-30 15:08:07,897 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:08:07,931 - jwst.outlier_detection.utils - INFO - 3813 pixels marked as outliers
# 2026-03-30 15:08:08,269 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:08:08,305 - jwst.outlier_detection.utils - INFO - 2346 pixels marked as outliers
# 2026-03-30 15:08:08,648 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:08:08,686 - jwst.outlier_detection.utils - INFO - 2920 pixels marked as outliers
# 2026-03-30 15:08:09,024 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:08:09,060 - jwst.outlier_detection.utils - INFO - 2879 pixels marked as outliers
# 2026-03-30 15:08:09,399 - stcal.outlier_detection.utils - INFO - Blotting (1024, 1032) <-- (1175, 1779)
# 2026-03-30 15:08:09,435 - jwst.outlier_detection.utils - INFO - 4652 pixels marked as outliers
# 2026-03-30 15:08:09,537 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/jw05952003001_04101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:08:09,619 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/jw05952003001_04101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:08:09,706 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/jw05952003001_04101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:08:09,795 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/jw05952003001_04101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:08:09,893 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/jw05952003002_04101_00001_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:08:09,982 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/jw05952003002_04101_00002_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:08:10,072 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/jw05952003002_04101_00003_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:08:10,160 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/jw05952003002_04101_00004_mirimage_fixed_wcs_a3001_crf.fits
# 2026-03-30 15:08:10,161 - stpipe.step - INFO - Step outlier_detection done
# 2026-03-30 15:08:10,259 - stpipe.step - INFO - Step resample running with args (<jwst.datamodels.library.ModelLibrary object at 0x12e8df650>,).
# 2026-03-30 15:08:10,353 - jwst.resample.resample_utils - INFO - Output pixel scale: 0.10999999999999999 arcsec.
# 2026-03-30 15:08:10,354 - jwst.resample.resample_utils - INFO - Computed pixel scale ratio (pscale_out/pscale_in): 0.9970271327537857.
# 2026-03-30 15:08:10,362 - stcal.resample.resample - INFO - Output pixel scale: 0.10999999999999999 arcsec.
# 2026-03-30 15:08:10,362 - stcal.resample.resample - INFO - Driz parameter kernel: square
# 2026-03-30 15:08:10,363 - stcal.resample.resample - INFO - Driz parameter pixfrac: 1.0
# 2026-03-30 15:08:10,363 - stcal.resample.resample - INFO - Driz parameter fillval: NAN
# 2026-03-30 15:08:10,363 - stcal.resample.resample - INFO - Driz parameter weight_type: exptime
# 2026-03-30 15:08:10,372 - jwst.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:10,681 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:10,785 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:10,887 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:10,988 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:11,458 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:11,562 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:11,664 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:11,766 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:12,230 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:12,336 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:12,438 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:12,540 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:12,989 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:13,094 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:13,196 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:13,298 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:13,730 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:13,835 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:13,937 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:14,037 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:14,480 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:14,585 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:14,687 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:14,788 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:15,215 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:15,319 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:15,421 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:15,523 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:15,952 - stcal.resample.resample - INFO - Resampling science and variance data
# 2026-03-30 15:08:16,056 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:16,158 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:16,259 - stcal.resample.resample - INFO - Drizzling (1024, 1032) --> (1184, 1794)
# 2026-03-30 15:08:16,569 - stcal.alignment.util - INFO - Update S_REGION to POLYGON ICRS  11.371359618 -73.347624895 11.249861643 -73.357489349 11.302023308 -73.410237600 11.423866182 -73.400342685
# 2026-03-30 15:08:16,746 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/miri_F770W_final_i2d.fits
# 2026-03-30 15:08:16,746 - stpipe.step - INFO - Step resample done
# 2026-03-30 15:08:16,857 - stpipe.step - INFO - Step source_catalog running with args (<ImageModel(1184, 1794) from miri_F770W_final_i2d.fits>,).
# 2026-03-30 15:08:16,935 - jwst.source_catalog.source_catalog_step - INFO - Using APCORR reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_apcorr_0014.fits
# 2026-03-30 15:08:16,938 - jwst.source_catalog.source_catalog_step - INFO - Using ABVEGAOFFSET reference file: /Users/melyajou/SMC_GO5952/crds_cache/references/jwst/miri/jwst_miri_abvegaoffset_0002.asdf
# 2026-03-30 15:08:16,939 - jwst.source_catalog.reference_data - INFO - Instrument: MIRI
# 2026-03-30 15:08:16,939 - jwst.source_catalog.reference_data - INFO - Detector: MIRIMAGE
# 2026-03-30 15:08:16,939 - jwst.source_catalog.reference_data - INFO - Filter: F770W
# 2026-03-30 15:08:16,940 - jwst.source_catalog.reference_data - INFO - Subarray: FULL
# 2026-03-30 15:08:16,968 - jwst.source_catalog.reference_data - INFO - AB to Vega magnitude offset 4.38398
# 2026-03-30 15:08:17,109 - jwst.tweakreg.tweakreg_catalog - INFO - Background could not be estimated in meshes. Using the entire unmasked array for background estimation: bkg_boxsize=(1184, 1794).
# 2026-03-30 15:08:17,798 - jwst.source_catalog.source_catalog_step - INFO - Wrote source catalog: /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/miri_F770W_final_cat.ecsv
# 2026-03-30 15:08:17,874 - stpipe.step - INFO - Saved model in /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/miri_F770W_final_segm.fits
# 2026-03-30 15:08:17,875 - jwst.source_catalog.source_catalog_step - INFO - Wrote segmentation map: miri_F770W_final_segm.fits
# 2026-03-30 15:08:17,876 - stpipe.step - INFO - Step source_catalog done
# 2026-03-30 15:08:17,880 - stpipe.step - INFO - Step Image3Pipeline done
# 2026-03-30 15:08:17,881 - jwst.stpipe.core - INFO - Results used jwst version: 1.20.2
# Mosaic: /Users/melyajou/SMC_GO5952/data/miri/F770W/stage3/miri_F770W_final_i2d.fits

# %%
final_sci = load_mosaic(mosaic)
m_ours = get_stats(final_sci)
plot_mosaic(final_sci, f'Final — {FILT}', f'{FILT}_final.png',
            fig_dir=fig_dir, stats_txt=stats_label(*m_ours))

# %% [markdown]
# ## 7. Comparison with MAST

# %%
mast_i2d = sorted(glob.glob(f'{mast_dir}/*_i2d.fits'))
if mast_i2d:
    mast_sci = load_mosaic(mast_i2d[0])
    m_mast = get_stats(mast_sci)
    plot_comparison(final_sci, mast_sci,
                    'This work', 'MAST standard',
                    f'{FILT}_comparison.png', fig_dir=fig_dir,
                    stats1=stats_label(*m_ours), stats2=stats_label(*m_mast))
    print(f'This work: σ = {m_ours[1]:.3f} MJy/sr')
    print(f'MAST:      σ = {m_mast[1]:.3f} MJy/sr')
else:
    print('No MAST reference found')
# Out:
# This work: σ = 0.579 MJy/sr
# MAST:      σ = 0.619 MJy/sr

# %% [markdown]
# ## 8. Source Catalog

# %%
plot_source_catalog(stage3, final_sci, FILT, fig_dir=fig_dir, dpi=FIG_DPI)
# Out:
# Catalog: 260 sources

# %% [markdown]
# ## 9. Summary

# %%
print_pipeline_summary(
    TARGET, PROGRAM, FILT, m_ours=m_ours,
    tile1_shifts=TILE1_SHIFTS, tile2_shifts=TILE2_SHIFTS,
    ipc_skip=IPC_SKIP, jump_threshold=JUMP_THRESHOLD,
    lyot_row=LYOT_ROW, lyot_col=LYOT_COL,
    pixel_scale=PIXEL_SCALE, pixfrac=PIXFRAC, kernel=KERNEL,
    tweakreg=TWEAKREG, skymatch=SKYMATCH,
    sky_subtract=SKY_SUBTRACT, outlier_det=OUTLIER_DET)
# Out:
# ==================================================
#   SMC-SW-Bar-3 (GO-5952) — F770W
# ==================================================
#
#   Result:
#     median = 4.957 MJy/sr
#     σ = 0.579 MJy/sr
#
#   WCS shifts:
#     Tile 1: [-0.1674, -0.1364]
#     Tile 2: [-0.1584, -0.1352]
#
#   Stage 1:
#     IPC:              SKIP
#     Jump threshold:   5.0σ
#
#   Lyot flag: row>700, col<310
#
#   Stage 3:
#     Pixel scale:      0.11 arcsec/pix
#     Pixfrac:          1.0
#     Kernel:           square
#     Tweakreg:         OFF
#     Skymatch:         OFF
#     Sky subtract:     OFF
#     Outlier det:      ON
# ==================================================
